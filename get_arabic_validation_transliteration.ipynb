# %% [markdown]
# # Disini sebagai pemotongan dataset Arabic, Transliteration, dan Validation

# %%
import pandas as pd

# **1️⃣ Load CSV**
quran_path = "pre_quran.csv"

# **2️⃣ Read CSV**
quran_df = pd.read_csv(quran_path, delimiter=";", dtype=str)

# **3️⃣ Pisahkan Data berdasarkan panjang kolom 'kemenag'**
df_less_equal_100 = quran_df[quran_df["kemenag"].str.len() <= 100]  # Panjang ≤ 100
df_more_than_100 = quran_df[quran_df["kemenag"].str.len() > 100]   # Panjang > 100

# **4️⃣ Simpan ke CSV baru**
df_less_equal_100.to_csv("quran_len_100.csv", index=False, sep=";", encoding="utf-8-sig")
#df_more_than_100.to_csv("quran_kemenag_>100.csv", index=False, sep=";", encoding="utf-8-sig")

# **5️⃣ Output hasil**
print(f"✅ Data dengan panjang 'kemenag' ≤ 100 disimpan di: quran_kemenag_≤100.csv")
#print(f"✅ Data dengan panjang 'kemenag' > 100 disimpan di: quran_kemenag_>100.csv")
# Out:
# ✅ Jumlah nilai di kolom 'kemenag' dengan panjang ≤ 100: 3314

# %%
import pandas as pd

# Baca file data.csv dan transcript.csv
data_df = pd.read_csv("quran_ayas.csv", delimiter=';')
transcript_df = pd.read_csv("transcript.csv", delimiter=';')

# Pilih kolom yang dibutuhkan dari data.csv
data_selected = data_df[['sura', 'aya', 'kemenag', 'transliteration_id']]

# Gabungkan dengan transcript.csv berdasarkan kolom 'sura' dan 'aya'
merged_df = data_selected.merge(transcript_df[['sura', 'aya', 'transcript']], on=['sura', 'aya'], how='left')

# Simpan ke file pre_quran.csv
merged_df.to_csv("pre_quran.csv", index=False, sep=';')

print("File berhasil disimpan: pre_quran.csv")
# Out:
# File berhasil disimpan: pre_quran.csv

# %% [markdown]
# ### Pemotongan sesuai panjang letter (100)

# %%
import pandas as pd

def split_arabic_text(text):
    """Membagi teks Arab menjadi beberapa bagian berdasarkan panjang teks"""
    if pd.isna(text):  # Jika teks kosong atau NaN, kembalikan daftar kosong
        return [""]
    
    text = str(text)  # Pastikan teks adalah string
    total_length = len(text.replace(" ", ""))  # Hitung panjang tanpa spasi

    # Menentukan jumlah bagian berdasarkan panjang teks
    if total_length <= 100:
        num_parts = 1
    elif total_length <= 160:
        num_parts = 2
    elif total_length <= 230:
        num_parts = 3
    else:
        num_parts = 4

    # Menentukan panjang setiap segmen (tanpa spasi)
    segment_length = total_length // num_parts
    words = text.split()  # Pisahkan teks berdasarkan spasi
    segments = []
    current_segment = []
    current_length = 0

    for word in words:
        current_length += len(word)  # Tambah panjang kata
        current_segment.append(word)
        
        # Jika panjang segmen cukup dan belum mencapai jumlah segmen yang diinginkan
        if current_length >= segment_length and len(segments) < num_parts - 1:
            segments.append(" ".join(current_segment))
            current_segment = []  # Reset segmen untuk bagian berikutnya
            current_length = 0

    # Tambahkan segmen terakhir
    segments.append(" ".join(current_segment))
    
    return segments

# Baca file pre_quran.csv
file_path = "pre_quran.csv"
df = pd.read_csv(file_path, delimiter=';')

# Pastikan kolom 'kemenag' ada dalam data
if "kemenag" not in df.columns:
    raise ValueError("Kolom 'kemenag' tidak ditemukan dalam file CSV.")

# List untuk menyimpan hasil
new_data = []

# Proses setiap baris
for index, row in df.iterrows():
    arabic_text = row["kemenag"]
    parts = split_arabic_text(arabic_text)  # Pisahkan teks Arab

    # Buat nomor bagian yang berulang untuk segmen
    for part_index, part in enumerate(parts, start=1):
        new_row = row.copy()
        new_row["kemenag_baru"] = part
        new_row["Bagian"] = part_index  # Nomor bagian berurutan
        new_data.append(new_row)

# Buat DataFrame baru dari hasil split
new_df = pd.DataFrame(new_data)

# Simpan ke file CSV baru
output_file = "quran_v1.csv"
new_df.to_csv(output_file, index=False, sep=';')

print(f"File berhasil disimpan: {output_file}")
# Out:
# File berhasil disimpan: quran_v1.csv

# %%
pip install arab-transliterator
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting arab-transliterator
#   Downloading arab_transliterator-1.0.3-py3-none-any.whl.metadata (5.7 kB)
# Downloading arab_transliterator-1.0.3-py3-none-any.whl (8.0 kB)
# Installing collected packages: arab-transliterator
# Successfully installed arab-transliterator-1.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
####fix

import csv
import re
from arab_transliterator.transliterator import ArabTransliterator

# Inisialisasi transliterator
Trans = ArabTransliterator()

# Nama file input & output
input_file = "quran_v1.csv"  # Ganti sesuai file Anda
output_csv = "quran_transliteration.csv"
translit_map = {
    "dh": "ż",
    "sh": "sy",
    "ʿ": "'",
    "gh": "g",
    "th": "ṡ",
    #"'":"`",
}
def adjust_transliteration(text):
    """Menyesuaikan transliterasi dengan aturan yang diberikan."""
    for old, new in translit_map.items():
        text = text.replace(old, new)
        text = re.sub(r" l-", "l", text)
        text = re.sub(r" s-","s-",text)
        text = re.sub(r" w-","w-",text)
        text = re.sub(r" d-","d-",text)
        text = re.sub(r" ṣ-","ṣ-",text)
        text = re.sub(r" z-","z-",text)
        text = re.sub(r" n-","n-",text)
        text = re.sub(r" m-","m-",text)
        text = re.sub(r" sy-","sy-",text)
        text = re.sub(r" j-","j-",text)
        text = re.sub(r" g-","g-",text)
        text = re.sub(r" f-","f-",text)
        text = re.sub(r" b-","b-",text)
        text = re.sub(r" ẓ-","ẓ-",text)
        text = re.sub(r" t-","t-",text)
        text = re.sub(r" r-","r-",text)
        text = re.sub(r" '-","'-",text)
        text = re.sub(r" ṡ-","ṡ-",text)
        text = re.sub(r" g-","g-",text)
        text = re.sub(r" ż-","ż-",text)
        text = re.sub(r" h-","h-",text)
        text = re.sub(r" ḍ-","ḍ-",text)
        text = re.sub(r" y-","y-",text)
        text = re.sub(r" ṭ-","ṭ-",text)
        text = re.sub(r" ḥ-","ḥ-",text)
        text = re.sub(r" q-","q-",text)
        text = re.sub(r"  "," ",text)
        text = re.sub("āa","ā a", text)
    return text
# Struktur hasil transliterasi

quran_data = []

# Pola regex untuk menghapus tanda baca wakaf
wakaf_pattern = re.compile(r'[\u06DA-\u06DC\u06DF-\u06E8\u06EA-\u06ED]')

# Pola regex untuk mendeteksi harakat akhir ayat
tanwin_kasrah = re.compile(r'ً|ٍ|ٌ$')
tanwin_fathah = re.compile(r'ً$')
tanwin_dammah = re.compile(r'ٌ$')
kasrah_akhir = re.compile(r'ِ$')
fathah_akhir = re.compile(r'َ$')
dammah_akhir = re.compile(r'ُ$')

def waqafkan_akhir(ayah):
    """Fungsi untuk mengubah harakat akhir ayat agar sesuai dengan aturan waqaf."""
    ayah = re.sub(wakaf_pattern, '', ayah)  # Hapus tanda wakaf

    # Ubah tanwin
    if re.search(tanwin_fathah, ayah):
        ayah = re.sub(tanwin_fathah, 'ا', ayah)
    elif re.search(tanwin_kasrah, ayah) or re.search(tanwin_dammah, ayah):
        ayah = re.sub(tanwin_kasrah, '', ayah)
        ayah = re.sub(tanwin_dammah, '', ayah)

    # Ubah harakat terakhir jadi sukun
    ayah = re.sub(kasrah_akhir, '', ayah)
    ayah = re.sub(dammah_akhir, '', ayah)
    ayah = re.sub(fathah_akhir, 'ا', ayah)

    return ayah

# Baca file CSV
with open(input_file, "r", encoding="utf-8") as f:
    reader = csv.reader(f, delimiter=";")
    header = next(reader)  # Ambil header

    # Simpan semua data dalam list untuk pengecekan kondisi
    quran_raw_data = list(reader)

# Looping dengan pengecekan kondisi 'Bagian'
for i, row in enumerate(quran_raw_data):
    if len(row) < 6:  # Pastikan baris memiliki cukup kolom
        continue

    sura = int(row[0])
    aya = int(row[1])
    arabic_text = row[5]
    trans_id = row[3]  # Transliteration dari kolom 'Bagian'

    # Cek apakah harus langsung pakai trans_id
    bagian = int(row[6])
    next_bagian = int(quran_raw_data[i+1][6]) if i+1 < len(quran_raw_data) and quran_raw_data[i+1][6].isdigit() else 0

    if bagian == 1 and next_bagian == 1:
        transliteration = trans_id  # Gunakan langsung dari file
    else:
        # Modifikasi teks agar sesuai dengan aturan waqaf
        arabic_text_waqaf = waqafkan_akhir(arabic_text)

        try:
            # Transliterate menggunakan arab-transliterator
            arabic_text_waqaf = arabic_text_waqaf.replace("ٰ","َا").replace("ٰ","َا")
            transliteration = Trans.translate(arabic_text_waqaf)
            transliteration = transliteration.replace("'","`")
            transliteration = adjust_transliteration(transliteration)
        except Exception as e:
            print(f"Kesalahan transliterasi pada Surah {sura} Ayat {aya}: {e}")
            transliteration = ""

    # Simpan ke dalam list
    quran_data.append([sura, aya,bagian, arabic_text, transliteration])

# Simpan ke file CSV
with open(output_csv, "w", encoding="utf-8", newline="") as f:
    writer = csv.writer(f, delimiter=";")
    writer.writerow(["Sura", "Aya", "Bagian" , "Arabic", "Transliteration"])
    writer.writerows(quran_data)

print(f"Data transliterasi telah disimpan di '{output_csv}'.")
# Out:
# Kesalahan transliterasi pada Surah 2 Ayat 26: list index out of range
# Kesalahan transliterasi pada Surah 6 Ayat 102: list index out of range
# Kesalahan transliterasi pada Surah 6 Ayat 154: list index out of range
# Kesalahan transliterasi pada Surah 9 Ayat 103: list index out of range
# Kesalahan transliterasi pada Surah 14 Ayat 4: list index out of range
# Kesalahan transliterasi pada Surah 14 Ayat 17: list index out of range
# Kesalahan transliterasi pada Surah 23 Ayat 27: list index out of range
# Kesalahan transliterasi pada Surah 39 Ayat 5: list index out of range
# Kesalahan transliterasi pada Surah 41 Ayat 12: list index out of range
# Kesalahan transliterasi pada Surah 65 Ayat 12: list index out of range
# Data transliterasi telah disimpan di 'quran_transliteration.csv'.

# %%
from arab_transliterator.transliterator import ArabTransliterator

def transliterate_with_diacritics(text):
    trans = ArabTransliterator()
    transliterated_text = trans.translate(text)
    
    diacritic_map = {
        "ً": "an", "ٌ": "un", "ٍ": "in",
        "َ": "a", "ُ": "u", "ِ": "i",
        "ّ": "",  # Shadda (handled separately)
        "ْ": "'",
        "ٰ": "َ"  # Dagger Alif
    }

    # Tambahkan diakritik sesuai mapping
    for arabic_char, translit in diacritic_map.items():
        transliterated_text = transliterated_text.replace(arabic_char, translit)
    
    return transliterated_text

arabic_text = "الَّذِيْنَ كَفَرُوْا فَيَقُوْلُوْنَ مَاذَآ اَرَادَ اللَّاهُ بِهَاذَا مَثَلا ۘ يُضِلّ"
print(transliterate_with_diacritics(arabic_text))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[65], line 22
#      19     return transliterated_text
#      21 arabic_text = "الَّذِيْنَ كَفَرُوْا فَيَقُوْلُوْنَ مَاذَآ اَرَادَ اللَّاهُ بِهَاذَا مَثَلا ۘ يُضِلّ"
# ---> 22 print(transliterate_with_diacritics(arabic_text))
#
# Cell In[65], line 5, in transliterate_with_diacritics(text)
#       3 def transliterate_with_diacritics(text):
#       4     trans = ArabTransliterator()
# ----> 5     transliterated_text = trans.translate(text)
#       7     diacritic_map = {
#       8         "ً": "an", "ٌ": "un", "ٍ": "in",
#       9         "َ": "a", "ُ": "u", "ِ": "i",
#    (...)
#      12         "ٰ": "َ"  # Dagger Alif
#      13     }
#      15     # Tambahkan diakritik sesuai mapping
#
# File ~/miniconda3/envs/310/lib/python3.10/site-packages/arab_transliterator/transliterator.py:28, in ArabTransliterator.translate(self, text)
#      26 def translate(self, text):
#      27     out = []
# ---> 28     text = normalize(text)
#      29     arabic_text = iter(ArabicText(text))
#      31     for caracter in arabic_text:
#      32         # handle hamza
#
# File ~/miniconda3/envs/310/lib/python3.10/site-packages/arab_transliterator/transliterator.py:14, in normalize(text)
#      12         if text[i - 1] in alphabet.VOWELS:
#      13             text[i], text[i - 1] = text[i - 1], text[i]
# ---> 14         elif (text[i - 1] == alphabet.LAM) and not (text[i + 1] in alphabet.VOWELS):
#      15             text.insert(i + 1, alphabet.FATHA)
#      16 return text
#
# IndexError: list index out of range

# %%
arabic_text = "الَّذِيْنَ كَفَرُوْا فَيَقُوْلُوْنَ مَاذَآ اَرَادَ اللَّاهُ بِهَاذَا مَثَلا ۘ يُضِلّ"
test = arabic_text.replace("ٰ","َا")
print(test)
# Out:
# الَّذِيْنَ كَفَرُوْا فَيَقُوْلُوْنَ مَاذَآ اَرَادَ اللَّاهُ بِهَاذَا مَثَلا ۘ يُضِلّ

# %%
from arab_transliterator.transliterator import ArabTransliterator

def transliterate_with_diacritics(text):
    trans = ArabTransliterator()
    
    try:
        transliterated_text = trans.translate(text)
    except IndexError as e:
        print(f"Error transliterating: {text} -> {e}")
        return ""

    diacritic_map = {
        "ً": "an", "ٌ": "un", "ٍ": "in",
        "َ": "a", "ُ": "u", "ِ": "i",
        "ّ": "",  # Shadda (handled separately)
        "ْ": "'",
        "ٰ": "َ"  # Dagger Alif
    }

    for arabic_char, translit in diacritic_map.items():
        transliterated_text = transliterated_text.replace(arabic_char, translit)

    return transliterated_text

arabic_text = "الَّذِيْنَ كَفَرُوْا فَيَقُوْلُوْنَ مَاذَآ اَرَادَ اللَّاهُ بِهَاذَا مَثَلا ۘ يُضِلّ"
print(transliterate_with_diacritics(arabic_text))
for i, char in enumerate(arabic_text):
    print(f"Index {i}: {char} (Unicode: {ord(char)})")
# Out:
# Error transliterating: الَّذِيْنَ كَفَرُوْا فَيَقُوْلُوْنَ مَاذَآ اَرَادَ اللَّاهُ بِهَاذَا مَثَلا ۘ يُضِلّ -> list index out of range
#
# Index 0: ا (Unicode: 1575)
# Index 1: ل (Unicode: 1604)
# Index 2: ّ (Unicode: 1617)
# Index 3: َ (Unicode: 1614)
# Index 4: ذ (Unicode: 1584)
# Index 5: ِ (Unicode: 1616)
# Index 6: ي (Unicode: 1610)
# Index 7: ْ (Unicode: 1618)
# Index 8: ن (Unicode: 1606)
# Index 9: َ (Unicode: 1614)
# Index 10:   (Unicode: 32)
# Index 11: ك (Unicode: 1603)
# Index 12: َ (Unicode: 1614)
# Index 13: ف (Unicode: 1601)
# Index 14: َ (Unicode: 1614)
# Index 15: ر (Unicode: 1585)
# Index 16: ُ (Unicode: 1615)
# Index 17: و (Unicode: 1608)
# Index 18: ْ (Unicode: 1618)
# Index 19: ا (Unicode: 1575)
# Index 20:   (Unicode: 32)
# Index 21: ف (Unicode: 1601)
# Index 22: َ (Unicode: 1614)
# Index 23: ي (Unicode: 1610)
# Index 24: َ (Unicode: 1614)
# Index 25: ق (Unicode: 1602)
# Index 26: ُ (Unicode: 1615)
# Index 27: و (Unicode: 1608)
# Index 28: ْ (Unicode: 1618)
# Index 29: ل (Unicode: 1604)
# Index 30: ُ (Unicode: 1615)
# Index 31: و (Unicode: 1608)
# Index 32: ْ (Unicode: 1618)
# Index 33: ن (Unicode: 1606)
# Index 34: َ (Unicode: 1614)
# Index 35:   (Unicode: 32)
# Index 36: م (Unicode: 1605)
# Index 37: َ (Unicode: 1614)
# Index 38: ا (Unicode: 1575)
# Index 39: ذ (Unicode: 1584)
# Index 40: َ (Unicode: 1614)
# Index 41: ا (Unicode: 1575)
# Index 42: ٓ (Unicode: 1619)
# Index 43:   (Unicode: 32)
# Index 44: ا (Unicode: 1575)
# Index 45: َ (Unicode: 1614)
# Index 46: ر (Unicode: 1585)
# Index 47: َ (Unicode: 1614)
# Index 48: ا (Unicode: 1575)
# Index 49: د (Unicode: 1583)
# Index 50: َ (Unicode: 1614)
# Index 51:   (Unicode: 32)
# Index 52: ا (Unicode: 1575)
# Index 53: ل (Unicode: 1604)
# Index 54: ل (Unicode: 1604)
# Index 55: ّ (Unicode: 1617)
# Index 56: َ (Unicode: 1614)
# Index 57: ا (Unicode: 1575)
# Index 58: ه (Unicode: 1607)
# Index 59: ُ (Unicode: 1615)
# Index 60:   (Unicode: 32)
# Index 61: ب (Unicode: 1576)
# Index 62: ِ (Unicode: 1616)
# Index 63: ه (Unicode: 1607)
# Index 64: َ (Unicode: 1614)
# Index 65: ا (Unicode: 1575)
# Index 66: ذ (Unicode: 1584)
# Index 67: َ (Unicode: 1614)
# Index 68: ا (Unicode: 1575)
# Index 69:   (Unicode: 32)
# Index 70: م (Unicode: 1605)
# Index 71: َ (Unicode: 1614)
# Index 72: ث (Unicode: 1579)
# Index 73: َ (Unicode: 1614)
# Index 74: ل (Unicode: 1604)
# Index 75: ا (Unicode: 1575)
# Index 76:   (Unicode: 32)
# Index 77: ۘ (Unicode: 1752)
# Index 78:   (Unicode: 32)
# Index 79: ي (Unicode: 1610)
# Index 80: ُ (Unicode: 1615)
# Index 81: ض (Unicode: 1590)
# Index 82: ِ (Unicode: 1616)
# Index 83: ل (Unicode: 1604)
# Index 84: ّ (Unicode: 1617)

# %%
import re
from arab_transliterator.transliterator import ArabTransliterator

def remove_diacritics(text):
    # Hapus harakat (tanda baca Arab)
    #text = re.sub(r"[\u0617-\u061A\u064B-\u065F\u0670\u06D6-\u06DC\u06DF-\u06E8\u06EA-\u06ED]", "", text)
    # Hapus karakter tidak umum seperti ۘ
    #text = re.sub(r"[^\u0600-\u06FF\s]", "", text)  
    return text
def normalize_shaddah(text):
    text = re.sub(r"(\w)ّ", r"\1\1", text)  # Ubah "لّ" menjadi "لل"
    return text
arabic_text = "الَّذِيْنَ كَفَرُوْا فَيَقُوْلُوْنَ مَاذَآ اَرَادَ اللَّاهُ بِهَاذَا مَثَلا ۘ يُضِلّ"
#arabic_text = normalize_shaddah(arabic_text)
#arabic_text = remove_diacritics(arabic_text)  # Normalisasi teks

trans = ArabTransliterator()
try:
    transliterated_text = trans.translate(arabic_text)
    print(transliterated_text)
except IndexError as e:
    print(f"Error: {e}")
# Out:
# Error: list index out of range

# %%
####fix

import csv
import re
from arab_transliterator.transliterator import ArabTransliterator
import unicodedata

# Inisialisasi transliterator
Trans = ArabTransliterator()

# Nama file input & output
input_file = "quran_v1.csv"  # Ganti sesuai file Anda
output_csv = "quran_transliteration.csv"
translit_map = {
    "dh": "ż",
    "sh": "sy",
    "ʿ": "'",
    "gh": "g",
    "th": "ṡ",
    #"'":"`",
}
#def normalize_shaddah(text):
#    text = re.sub(r"(\w)ّ", r"\1\1", text)  # Ubah "لّ" menjadi "لل"
#    return text
def adjust_transliteration(text):
    """Menyesuaikan transliterasi dengan aturan yang diberikan."""
    for old, new in translit_map.items():
        text = text.replace(old, new)
        text = re.sub(r" l-", "l", text)
        text = re.sub(r" s-","s-",text)
        text = re.sub(r" w-","w-",text)
        text = re.sub(r" d-","d-",text)
        text = re.sub(r" ṣ-","ṣ-",text)
        text = re.sub(r" z-","z-",text)
        text = re.sub(r" n-","n-",text)
        text = re.sub(r" m-","m-",text)
        text = re.sub(r" sy-","sy-",text)
        text = re.sub(r" j-","j-",text)
        text = re.sub(r" g-","g-",text)
        text = re.sub(r" f-","f-",text)
        text = re.sub(r" b-","b-",text)
        text = re.sub(r" ẓ-","ẓ-",text)
        text = re.sub(r" t-","t-",text)
        text = re.sub(r" r-","r-",text)
        text = re.sub(r" '-","'-",text)
        text = re.sub(r" ṡ-","ṡ-",text)
        text = re.sub(r" g-","g-",text)
        text = re.sub(r" ż-","ż-",text)
        text = re.sub(r" h-","h-",text)
        text = re.sub(r" ḍ-","ḍ-",text)
        text = re.sub(r" y-","y-",text)
        text = re.sub(r" ṭ-","ṭ-",text)
        text = re.sub(r" ḥ-","ḥ-",text)
        text = re.sub(r" q-","q-",text)
        text = re.sub(r"  "," ",text)
        text = re.sub("āa","ā a", text)
    return text
# Struktur hasil transliterasi

quran_data = []

# Pola regex untuk menghapus tanda baca wakaf
wakaf_pattern = re.compile(r'[\u06DA-\u06DC\u06DF-\u06E8\u06EA-\u06ED]')

# Pola regex untuk mendeteksi harakat akhir ayat
tanwin_kasrah = re.compile(r'ً|ٍ|ٌ$')
tanwin_fathah = re.compile(r'ً$')
tanwin_dammah = re.compile(r'ٌ$')
kasrah_akhir = re.compile(r'ِ$')
fathah_akhir = re.compile(r'َ$')
dammah_akhir = re.compile(r'ُ$')

def waqafkan_akhir(ayah):
    """Fungsi untuk mengubah harakat akhir ayat agar sesuai dengan aturan waqaf."""
    ayah = re.sub(wakaf_pattern, '', ayah)  # Hapus tanda wakaf

    # Ubah tanwin
    if re.search(tanwin_fathah, ayah):
        ayah = re.sub(tanwin_fathah, 'ا', ayah)
    elif re.search(tanwin_kasrah, ayah) or re.search(tanwin_dammah, ayah):
        ayah = re.sub(tanwin_kasrah, '', ayah)
        ayah = re.sub(tanwin_dammah, '', ayah)

    # Ubah harakat terakhir jadi sukun
    ayah = re.sub(kasrah_akhir, '', ayah)
    ayah = re.sub(dammah_akhir, '', ayah)
    ayah = re.sub(fathah_akhir, 'ا', ayah)

    return ayah

# Baca file CSV
with open(input_file, "r", encoding="utf-8") as f:
    reader = csv.reader(f, delimiter=";")
    header = next(reader)  # Ambil header

    # Simpan semua data dalam list untuk pengecekan kondisi
    quran_raw_data = list(reader)

# Looping dengan pengecekan kondisi 'Bagian'
for i, row in enumerate(quran_raw_data):
    if len(row) < 6:  # Pastikan baris memiliki cukup kolom
        continue

    sura = int(row[0])
    aya = int(row[1])
    arabic_text = row[5]
    trans_id = row[3]  # Transliteration dari kolom 'Bagian'

    # Cek apakah harus langsung pakai trans_id
    if len(row) < 7 or not row[6].isdigit():
        print(f"Baris tidak valid di Surah {sura} Ayat {aya}: {row}")
        continue

    bagian = int(row[6])
    if i+1 < len(quran_raw_data) and len(quran_raw_data[i+1]) > 6 and quran_raw_data[i+1][6].isdigit():
        next_bagian = int(quran_raw_data[i+1][6])
    else:
        next_bagian = 0


    if bagian == 1 and next_bagian == 1:
        transliteration = trans_id  # Gunakan langsung dari file
    else:
        # Modifikasi teks agar sesuai dengan aturan waqaf
        arabic_text_waqaf = arabic_text

        try:
            # Transliterate menggunakan arab-transliterator
            arabic_text_waqaf = arabic_text_waqaf.replace("ٰ","َا").replace("ٰ","َا")
            #arabic_text_waqaf = re.sub(r"[^\u0600-\u06FF\s]", "", arabic_text_waqaf)
            #arabic_text_waqaf = normalize_shaddah(arabic_text_waqaf)
            #arabic_text_waqaf = unicodedata.normalize("NFKD", arabic_text_waqaf)
            transliteration = Trans.translate(arabic_text_waqaf)
            transliteration = transliteration.replace("'","`")
            transliteration = adjust_transliteration(transliteration)
        except Exception as e:
            print(f"Kesalahan transliterasi pada Surah {sura} Ayat {aya}: {e}")
            print(arabic_text_waqaf)
            print(transliteration)
            transliteration = ""

    # Simpan ke dalam list
    quran_data.append([sura, aya,bagian, arabic_text, transliteration])

# Simpan ke file CSV
with open(output_csv, "w", encoding="utf-8", newline="") as f:
    writer = csv.writer(f, delimiter=";")
    writer.writerow(["Sura", "Aya", "Bagian" , "Arabic", "Transliteration"])
    writer.writerows(quran_data)

print(f"Data transliterasi telah disimpan di '{output_csv}'.")
# Out:
# Data transliterasi telah disimpan di 'quran_transliteration.csv'.

# %%
### transliteration updated

import pandas as pd
from difflib import SequenceMatcher

# **1️⃣ Load CSV Files**
transliteration_path = "quran_transliteration.csv"
quran_v1_path = "quran_v1.csv"

# **2️⃣ Read CSV Files**
transliteration_df = pd.read_csv(transliteration_path, delimiter=";")
quran_v1_df = pd.read_csv(quran_v1_path, delimiter=";")

# **3️⃣ Ensure column names match**
transliteration_df.columns = ["Sura", "Aya", "Bagian", "Arabic", "Transliteration"]
quran_v1_df.columns = ["sura", "aya", "kemenag", "transliteration_id", "transcript", "kemenag_baru", "Bagian"]

# **4️⃣ Convert columns to string for accurate matching**
transliteration_df["Sura"] = transliteration_df["Sura"].astype(str)
transliteration_df["Aya"] = transliteration_df["Aya"].astype(str)
quran_v1_df["sura"] = quran_v1_df["sura"].astype(str)
quran_v1_df["aya"] = quran_v1_df["aya"].astype(str)

# **5️⃣ Create a dictionary mapping (sura, aya) to transliteration_id**
transliteration_dict = {}
for _, row in quran_v1_df.iterrows():
    key = (row["sura"], row["aya"])
    transliteration_dict[key] = row["transliteration_id"]

# **6️⃣ Function to find the most similar transliteration substring**
def find_most_similar(original_text, full_text):
    """Finds the most similar substring in full_text that matches original_text length"""
    best_match = ""
    best_ratio = 0.0

    for i in range(len(full_text) - len(original_text) + 1):
        candidate = full_text[i : i + len(original_text)]
        ratio = SequenceMatcher(None, original_text, candidate).ratio()
        if ratio > best_ratio:
            best_ratio = ratio
            best_match = candidate

    return best_match

# **7️⃣ Replace Transliteration**
for idx, row in transliteration_df.iterrows():
    key = (row["Sura"], row["Aya"])
    
    if key in transliteration_dict:
        full_transliteration = transliteration_dict[key]
        original_translit = row["Transliteration"]
        
        # Cari bagian transliterasi yang paling mirip dengan posisi aslinya
        best_match = find_most_similar(original_translit, full_transliteration)
        transliteration_df.at[idx, "Transliteration"] = best_match

# **8️⃣ Save Updated CSV**
output_path = "quran_transliteration_updated.csv"
transliteration_df.to_csv(output_path, index=False, sep=";", encoding="utf-8-sig")

print(f"✅ Transliterasi diperbarui dan disimpan ke {output_path}")
# Out:
# ✅ Transliterasi diperbarui dan disimpan ke quran_transliteration_updated.csv

# %%
import pandas as pd
from difflib import SequenceMatcher
import re

# **1️⃣ Load CSV Files**
transliteration_path = "quran_transliteration_updated.csv"
quran_v1_path = "quran_v1.csv"

# **2️⃣ Read CSV Files**
transliteration_df = pd.read_csv(transliteration_path, delimiter=";")
quran_v1_df = pd.read_csv(quran_v1_path, delimiter=";")

# **3️⃣ Ensure column names match**
transliteration_df.columns = ["Sura", "Aya", "Bagian", "Arabic", "Transliteration"]
quran_v1_df.columns = ["sura", "aya", "kemenag", "transliteration_id", "transcript", "kemenag_baru", "Bagian"]

# **4️⃣ Convert columns to string for accurate matching**
transliteration_df["Sura"] = transliteration_df["Sura"].astype(str)
transliteration_df["Aya"] = transliteration_df["Aya"].astype(str)
quran_v1_df["sura"] = quran_v1_df["sura"].astype(str)
quran_v1_df["aya"] = quran_v1_df["aya"].astype(str)

# **5️⃣ Create a dictionary mapping (sura, aya) to transcript**
transcript_dict = {}
for _, row in quran_v1_df.iterrows():
    key = (row["sura"], row["aya"])
    # Hapus "-" dan spasi sebelum disimpan
    cleaned_transcript = re.sub(r"[-\s]", "", row["transcript"])
    transcript_dict[key] = cleaned_transcript

# **6️⃣ Function to find the most similar transcript substring**
def find_most_similar(original_text, full_text):
    """Finds the most similar substring in full_text that matches original_text length"""
    best_match = ""
    best_ratio = 0.0

    # Hapus "-" dan spasi dari teks transliterasi
    cleaned_original = re.sub(r"[-\s]", "", original_text)

    for i in range(len(full_text) - len(cleaned_original) + 1):
        candidate = full_text[i : i + len(cleaned_original)]
        ratio = SequenceMatcher(None, cleaned_original, candidate).ratio()
        if ratio > best_ratio:
            best_ratio = ratio
            best_match = candidate

    return best_match

# **7️⃣ Add Transcript Column**
transliteration_df["Transcript"] = ""

for idx, row in transliteration_df.iterrows():
    key = (row["Sura"], row["Aya"])
    
    if key in transcript_dict:
        full_transcript = transcript_dict[key]
        original_translit = row["Transliteration"]
        
        # Cari bagian transcript yang paling mirip dengan posisi aslinya
        best_match = find_most_similar(original_translit, full_transcript)
        transliteration_df.at[idx, "Transcript"] = best_match

# **8️⃣ Save Updated CSV**
output_path = "quran_transliteration_with_transcript.csv"
transliteration_df.to_csv(output_path, index=False, sep=";", encoding="utf-8-sig")

print(f"✅ Kolom 'transcript' ditambahkan dan disimpan ke {output_path}")
# Out:
# ✅ Kolom 'transcript' ditambahkan dan disimpan ke quran_transliteration_with_transcript.csv

# %%
import pandas as pd
import re
from difflib import SequenceMatcher

# **1️⃣ Load CSV Files**
transliteration_path = "quran_transliteration_updated.csv"
quran_v1_path = "quran_v1.csv"

# **2️⃣ Read CSV Files**
transliteration_df = pd.read_csv(transliteration_path, delimiter=";")
quran_v1_df = pd.read_csv(quran_v1_path, delimiter=";")

# **3️⃣ Ensure column names match**
transliteration_df.columns = ["Sura", "Aya", "Bagian", "Arabic", "Transliteration"]
quran_v1_df.columns = ["sura", "aya", "kemenag", "transliteration_id", "transcript", "kemenag_baru", "Bagian"]

# **4️⃣ Convert columns to string for accurate matching**
transliteration_df["Sura"] = transliteration_df["Sura"].astype(str)
transliteration_df["Aya"] = transliteration_df["Aya"].astype(str)
quran_v1_df["sura"] = quran_v1_df["sura"].astype(str)
quran_v1_df["aya"] = quran_v1_df["aya"].astype(str)

# **5️⃣ Create a dictionary mapping (sura, aya) to transcript**
transcript_dict = {
    (row["sura"], row["aya"]): row["transcript"] for _, row in quran_v1_df.iterrows()
}

# **6️⃣ Function to Find Best Matching Substring in Transcript**
def find_best_match(transliteration, full_transcript):
    """
    Mencari bagian terbaik dalam transcript yang sesuai dengan transliteration.
    ✅ Gunakan SequenceMatcher untuk mencari start & end yang paling cocok.
    ✅ Pastikan substring yang diambil **mengandung transliteration secara penuh**.
    """
    if not isinstance(full_transcript, str) or not isinstance(transliteration, str):
        return ""

    # Hapus semua spasi & tanda hubung dari transliteration dan transcript
    translit_clean = re.sub(r"[-\s]", "", transliteration)
    transcript_clean = re.sub(r"[-\s]", "", full_transcript)

    # Gunakan SequenceMatcher untuk mencari kecocokan terbaik
    match = SequenceMatcher(None, transcript_clean, translit_clean).find_longest_match(0, len(transcript_clean), 0, len(translit_clean))

    if match.size == 0:
        return ""  # Jika tidak ada kecocokan, kembalikan string kosong

    # **Ambil substring terbaik dari transcript dengan padding ekstra untuk kelengkapan**
    start = max(0, match.a - 5)  # Tambah toleransi 5 karakter ke belakang
    end = min(len(transcript_clean), match.a + match.size + 5)  # Tambah 5 karakter ke depan
    #print("end_word", end)
    return full_transcript[start:end]

# **7️⃣ Add Transcript Column**
transliteration_df["Transcript"] = ""

for idx, row in transliteration_df.iterrows():
    key = (row["Sura"], row["Aya"])

    if key in transcript_dict:
        full_transcript = transcript_dict[key]
        transliteration = row["Transliteration"]
        
        # Cari bagian transcript yang paling mirip dengan transliteration
        best_match = find_best_match(transliteration, full_transcript)
        #print(best_match)
        transliteration_df.at[idx, "Transcript"] = best_match

# **8️⃣ Save Updated CSV**
output_path = "quran_transliteration_with_transcript_fixed.csv"
transliteration_df.to_csv(output_path, index=False, sep=";", encoding="utf-8-sig")

print(f"✅ Kolom 'Transcript' telah diperbaiki dan disimpan ke {output_path}")
# Out:
# end_word 24
# bis mil lā hir raḥ mā ni
# end_word 27
# al ḥam du lil lā hi rab bil
# end_word 15
# ar raḥ mā nir r
# end_word 15
# mā li ki yau mi
# end_word 29
# iy yā ka na' bu du wa iy yā k
# end_word 22
# ih di naṣ ṣi rā ṭal mu
# end_word 60
# ṣi rā ṭal la żī na an 'am ta 'a lai him gai ril mag ḍụ bi 'a
# end_word 10
# a lif lām
# end_word 40
# żā li kal ki tā bu lā rai ba fīh , hu da
# end_word 67
# al la żī na yu` mi nụ na bil gai bi wa yu qī mụ naṣ ṣa lā ta wa mim
# end_word 43
# wal la żī na yu` mi nụ na bi mā un zi la i
# end_word 78
# n zi la i lai ka wa mā un zi la ming qab lik
# end_word 49
# u lā `i ka 'a lā hu dam mir rab bi him wa u lā `i
# end_word 67
# in nal la żī na ka fa rụ sa wā `un 'a lai him a an żar ta hum am la
# end_word 51
# ta mall llā hu 'a lā qu lụ bi him wa 'a lā sam
# end_word 86
# a lā sam 'i him , wa 'a lā ab ṣā ri him gi s
# end_word 67
# wa mi nan nā si may ya qụ lu ā man nā bil lā hi wa bil yau mil ā kh
# end_word 73
# i 'ụ nall llā ha wal la żī na ā ma nụ , wa mā yakh da 'ụ na il lā
# end_word 35
# fī qu lụ bi him ma ra ḍun fa zā da
# end_word 78
#  mull llā hu ma ra ḍā , wa la hum 'a żā b
# end_word 53
# wa i żā qī la la hum lā tuf si dụ fil ar ḍi qā lū in
# end_word 42
# a lā in na hum hu mul muf si dụ na wa lā k
# end_word 59
# wa i żā qī la la hum ā mi nụ ka mā ā ma nan nā su qā lū a n
# end_word 103
# su qā lū a nu` mi nu ka mā ā ma nas su fa hā` , a lā in
# end_word 51
# wa i żā la qul la żī na ā ma nụ qā lū ā man nā , wa
# end_word 95
# an nā , wa i żā kha lau i lā sya yā ṭī ni him qā lū in
# end_word 55
# all llā hu yas tah zi `u bi him wa ya mud du hum fī ṭug
# end_word 43
# u lā `i kal la żī nasy ta ra wuḍ ḍa lā la t
# end_word 76
# ḍa lā la ta bil hu dā fa mā ra bi ḥat ti jā
# end_word 62
# ma ṡa lu hum ka ma ṡa lil la żis tau qa da nā rā , fa lam mā a
# end_word 111
#  a ḍā `at mā ḥau la hụ ża ha ball llā hu bi nụ ri h
# end_word 33
# ṣum mum buk mun 'um yun fa hum lā
# end_word 56
# au ka ṣay yi bim mi nas sa mā `i fī hi ẓu lu mā tuw wa r
# end_word 98
# ā tuw wa ra' duw wa barq , yaj 'a lụ na a ṣā bi 'a h
# end_word 131
# ā żā ni him mi naṣ ṣa wā 'i
# end_word 57
# ya kā dul bar qu yakh ṭa fu ab ṣā ra hum , kul la mā a ḍā
# end_word 98
# a mā a ḍā `a la hum ma syau fī hi wa i żā aẓ la ma
# end_word 139
#  lai him qā mụ , wa lau syā `all llā h
# end_word 47
# yā ay yu han nā su' bu dụ rab ba ku mul la żī k
# end_word 81
# ul la żī kha la qa kum wal la żī na ming qab
# end_word 60
# al la żī ja 'a la la ku mul ar ḍa fi rā syaw was sa mā `a bi
# end_word 113
# a mā `a bi nā `aw wa an za la mi nas sa mā `i mā `an fa akh ra
# end_word 149
# a akh ra ja bi hī mi naṡ ṡa ma rā ti riz qal
# end_word 63
# wa ing kun tum fī rai bim mim mā naz zal nā 'a lā 'ab di nā fa`
# end_word 112
# i nā fa` tụ bi sụ ra tim mim miṡ li hī wad 'ụ syu ha dā `
# end_word 48
# fa il lam taf 'a lụ wa lan taf 'a lụ fat ta qun
# end_word 84
# at ta qun nā ral la tī wa qụ du han nā su wal
# end_word 65
# wa basy syi ril la żī na ā ma nụ wa 'a mi luṣ ṣā li ḥā ti an na l
# end_word 117
#  an na la hum jan nā tin taj rī min taḥ ti hal an hār , kul
# end_word 174
# , kul la mā ru zi qụ min hā min ṡa ma ra tir riz qang qā lụ hā
# end_word 213
# lụ hā żal la żī ru ziq nā ming qab lu wa u tụ
# end_word 64
# n nall llā ha lā yas taḥ yī ay yaḍ ri ba ma ṡa lam mā ba 'ụ ḍa
# end_word 123
#  'ụ ḍa tan fa mā fau qa hā , fa am mal la żī na ā ma nụ fa ya' la
# end_word 158
#  ya' la mụ na an na hul ḥaq qu mir rab bi h
# end_word 234
# ī na ka fa rụ fa ya qụ lụ na mā żā a rā dall llā hu bi hā
# end_word 30
# al la żī na yang qu ḍụ na 'ah
# end_word 96
#  hī wa yaq ṭa 'ụ na mā a ma rall ll
# end_word 121
# rall llā hu bi hī ay yụ ṣa la wa
# end_word 50
# kai fa tak fu rụ na bil lā hi wa kun tum am wā tan
# end_word 92
# am wā tan fa aḥ yā kum , ṡum ma yu mī tu kum ṡum ma
# end_word 55
# hu wal la żī kha la qa la kum mā fil ar ḍi ja mī 'an ṡu
# end_word 107
#  ja mī 'an ṡum mas ta wā i las sa mā `i fa saw wā hun na sab 'a s
# end_word 64
# wa iż qā la rab bu ka lil ma lā `i ka ti in nī jā 'i lun fil ar
# end_word 122
# n fil ar ḍi kha lī fah , qā lū a taj 'a lu fī hā may yuf si du fī h
# end_word 167
# si du fī hā wa yas fi kud di mā` , wa naḥ nu nu sab bi
# end_word 60
# wa 'al la ma ā da mal as mā `a kul la hā ṡum ma 'a ra ḍa hum
# end_word 104
# ra ḍa hum 'a lal ma lā `i ka ti fa qā la am bi `ụ nī
# end_word 64
# qā lụ sub ḥā na ka lā 'il ma la nā il lā mā 'al lam ta nā , in n
# end_word 52
# qā la yā ā da mu am bi` hum bi `as mā `i him , fa la
# end_word 104
# m , fa lam mā am ba `a hum bi `as mā `i him qā la a lam a qul
# end_word 143
# am a qul la kum in nī a' la mu gai bas sa mā wā
# end_word 52
# wa iż qul nā lil ma lā `i ka tis ju dụ li `ā da ma f
# end_word 84
# `ā da ma fa sa ja dū il lā ib līs , a bā w
# end_word 63
# wa qul nā yā ā da mus kun an ta wa zau ju kal jan na ta wa ku l
# end_word 118
# a ku lā min hā ra ga dan ḥai ṡu syi` tu mā wa lā taq ra bā hā
# end_word 53
# fa a zal la hu masy syai ṭā nu 'an hā fa akh ra ja hu
# end_word 99
#  ra ja hu mā mim mā kā nā fī hi wa qul nah bi ṭụ ba' ḍu
# end_word 128
# ṭụ ba' ḍu kum li ba' ḍin 'a duww , wa
# end_word 70
# fa ta laq qā ā da mu mir rab bi hī ka li mā tin fa tā ba 'a laīh , in
# end_word 50
# qul nah bi ṭụ min hā ja mī 'ā , fa im mā ya` ti ya
# end_word 102
# ya` ti yan na kum min nī hu dan fa man ta bi 'a hu dā ya fa l
# end_word 67
# wal la żī na ka fa rụ wa każ ża bụ bi `ā yā ti nā u lā `i ka aṣ ḥā
# end_word 53
# yā ba nī is rā `ī laż ku rụ ni' ma ti yal la tī an 'a
# end_word 91
# a tī an 'am tu 'a lai kum wa au fụ bi 'ah dī ụ f
# end_word 66
# wa ā mi nụ bi mā an zal tu mu ṣad di qal li mā ma 'a kum wa lā ta
# end_word 116
# wa lā ta kụ nū aw wa la kā fi rim bi hī wa lā tasy ta rụ bi
# end_word 56
# wa lā tal bi sul ḥaq qa bil bā ṭi li wa tak tu mul ḥaq q
# end_word 45
# wa a qī muṣ ṣa lā ta wa ā tuz za kā ta war ka
# end_word 46
# a ta` mu rụ nan nā sa bil bir ri wa tan sau na
# end_word 76
# an sau na an fu sa kum wa an tum tat lụ
# end_word 63
# was ta 'ī nụ biṣ ṣab ri waṣ ṣa lāh , wa in na hā la ka bī ra tu
# end_word 60
# al la żī na ya ẓun nụ na an na hum mu lā qụ rab bi him wa an
# end_word 45
# yā ba nī is rā `ī laż ku rụ ni' ma ti yal la
# end_word 77
# ti yal la tī an 'am tu 'a lai kum wa an nī
# end_word 57
# wat ta qụ yau mal lā taj zī naf sun 'an naf sin syai `aw
# end_word 106
# syai `aw wa lā yuq ba lu min hā sya fā 'a tuw wa lā yu` kh
# end_word 49
# wa iż naj jai nā kum min ā li fir 'au na ya sụ mụ
# end_word 97
# na ya sụ mụ na kum sū `al 'a żā bi yu żab bi ḥụ na ab nā `a
# end_word 127
# na ab nā `a kum wa yas taḥ yụ na ni sā `a
# end_word 70
# wa iż fa raq nā bi ku mul baḥ ra fa an jai nā kum wa ag raq nā ā la fi
# end_word 52
# wa iż wā 'ad nā mụ sā ar ba 'ī na lai la tan ṡum mat
# end_word 77
# an ṡum mat ta khaż tu mul 'ij la mi
# end_word 52
# ṡum ma 'a fau nā 'ang kum mim ba' di żā li ka la 'al
# end_word 49
# wa iż ā tai nā mụ sal ki tā ba wal fur qā na la '
# end_word 57
# wa iż qā la mụ sā li qau mi hī yā qau mi in na kum ẓa lam
# end_word 101
# kum ẓa lam tum an fu sa kum bit ti khā żi ku mul 'ij l
# end_word 149
# mul 'ij la fa tụ bū i lā bā ri `i kum faq tu lū an fu sa
# end_word 180
#  fu sa kum , żā li kum khai rul la kum
# end_word 46
# wa iż qul tum yā mụ sā lan nu` mi na la ka ḥat
# end_word 91
# a ḥat tā na rall llā ha jah ra tan fa a kha żat ku
# end_word 50
# ṡum ma ba 'aṡ nā kum mim ba' di mau ti kum la 'al
# end_word 55
# wa ẓal lal nā 'a lai ku mul ga mā ma wa an zal nā 'a la
# end_word 105
# ā 'a lai ku mul man na was sal wā , ku lụ min ṭay yi bā t
# end_word 129
# ay yi bā ti mā ra zaq nā kum , wa
# end_word 50
# wa iż qul nad khu lụ hā żi hil qar ya ta fa ku lụ
# end_word 97
#  fa ku lụ min hā ḥai ṡu syi` tum ra ga daw wad khu lul bā
# end_word 135
# u lul bā ba suj ja daw wa qụ lụ ḥiṭ ṭa tun nag
# end_word 60
# fa bad da lal la żī na ẓa la mụ qau lan gai ral la żī qī la
# end_word 106
# a żī qī la la hum fa an zal nā 'a lal la żī na ẓa la mụ r
# end_word 65
# wa i żis tas qā mụ sā li qau mi hī fa qul naḍ rib bi 'a ṣā kal ḥa
# end_word 132
#  ṣā kal ḥa jar , fan fa ja rat min huṡ na tā 'asy ra ta 'ai nā , qad 'a li ma
# end_word 166
#  'a li ma kul lu u nā sim masy ra ba hum ,
# end_word 103
# wa iż qul tum yā mụ sā lan naṣ bi ra 'a lā ṭa 'ā miw wā ḥi din fad 'u la nā rab ba ka yukh rij la nā mi
# end_word 200
# la nā mim mā tum bi tul ar ḍu mim baq li hā wa qiṡ ṡā `i hā wa fụ mi hā wa 'a da si hā wa ba ṣa li hā , q
# end_word 283
# hā , qā la a tas tab di lụ nal la żī hu wa ad nā bil la żī hu wa khaīr , ih bi ṭụ miṣ ran
# end_word 388
# m mā sa `al tum , wa ḍu ri bat 'a lai hi muż żil la tu wal mas ka na tu wa bā `ụ bi ga ḍa
# end_word 53
# in nal la żī na ā ma nụ wal la żī na hā dụ wan na ṣā
# end_word 109
# an na ṣā rā waṣ ṣā bi `ī na man ā ma na bil lā hi wal yau mil ā k
# end_word 156
# il ā khi ri wa 'a mi la ṣā li ḥan fa la hum aj ru hum
# end_word 55
# wa iż a khaż nā mī ṡā qa kum wa ra fa' nā fau qa ku muṭ
# end_word 100
#  qa ku muṭ ṭụr , khu żụ mā ā tai nā kum bi quw wa tiw w
# end_word 49
# ṡum ma ta wal lai tum mim ba' di żā li ka fa lau
# end_word 89
#  lau lā faḍ lull llā hi 'a lai kum wa raḥ ma
# end_word 48
# wa la qad 'a lim tu mul la żī na' ta dau ming ku
# end_word 77
# u ming kum fis sab ti fa qul nā la hum
# end_word 69
# fa ja 'al nā hā na kā lal li mā bai na ya dai hā wa mā khal fa hā wa
# end_word 68
# au mi hī in nall llā ha ya` mu ru kum an taż b
# end_word 118
#  an taż ba ḥụ ba qa rah , qā lū a tat ta khi żu nā hu zu wā
# end_word 72
# qā lud 'u la nā rab ba ka yu bay yil la nā mā hiy , qā la in na hụ ya qụ
# end_word 120
# a hụ ya qụ lu in na hā ba qa ra tul lā fā ri ḍuw wa lā bik
# end_word 60
# qā lud 'u la nā rab ba ka yu bay yil la nā mā lau nu hā , qā
# end_word 107
# u hā , qā la in na hụ ya qụ lu in na hā ba qa ra tun ṣaf
# end_word 52
# qā lud 'u la nā rab ba ka yu bay yil la nā mā hi ya
# end_word 84
#  mā hi ya in nal ba qa ra ta syā ba ha 'a
# end_word 54
# qā la in na hụ ya qụ lu in na hā ba qa ra tul lā ża lụ
# end_word 102
# lā ża lụ lun tu ṡī rul ar ḍa wa lā tas qil ḥarṡ , mu sal
# end_word 139
#  mu sal la ma tul lā syi ya ta fī hā , qā lu
# end_word 43
# wa iż qa tal tum naf san fad dā ra' tum fī
# end_word 46
# fa qul naḍ ri bụ hu bi ba' ḍi hā , ka żā li ka
# end_word 82
# a żā li ka yuḥ yil lā hul mau tā wa yu rī kum
# end_word 62
# ṡum ma qa sat qu lụ bu kum mim ba' di żā li ka fa hi ya kal ḥi
# end_word 119
# a kal ḥi jā ra ti au a syad du qas wah , wa in na mi nal ḥi jā ra
# end_word 185
#  ra ti la mā ya ta faj ja ru min hul an hār , wa in na min hā la mā y
# end_word 231
#  fa yakh ru ju min hul mā` , wa
# end_word 59
# a fa taṭ ma 'ụ na ay yu` mi nụ la kum wa qad kā na fa rī qu
# end_word 119
#  min hum yas ma 'ụ na ka lā mall llā hi ṡum ma yu ḥar ri fụ
# end_word 55
# wa i żā la qul la żī na ā ma nụ qā lū ā man nā , wa i ż
# end_word 96
# ā , wa i żā kha lā ba' ḍu hum i lā ba' ḍing qā lū a
# end_word 147
#  ḥad di ṡụ na hum bi mā fa ta ḥall llā hu 'a lai
# end_word 55
# mụ na an nall llā ha ya' la mu mā yu sir
# end_word 66
# wa min hum um miy yụ na lā ya' la mụ nal ki tā ba il lā a mā niy y
# end_word 58
# fa wai lul lil la żī na yak tu bụ nal ki tā ba bi `ai dī h
# end_word 117
# ai dī him ṡum ma ya qụ lụ na hā żā min 'in dil lā hi li yasy ta rụ
# end_word 160
# y ta rụ bi hī ṡa ma nang qa lī lā , fa wai lul la
# end_word 48
# wa qā lụ lan ta mas sa nan nā ru il lā ay yā mam
# end_word 95
#  , qul at ta khaż tum 'in dall llā h
# end_word 123
# llā hi 'ah dan fa lay yukh li fal
# end_word 50
# ba lā mang ka sa ba say yi `a taw wa `a ḥā ṭat bi
# end_word 83
# ṭat bi hī kha ṭī `a tu hụ fa u lā `i ka
# end_word 67
# wal la żī na ā ma nụ wa 'a mi luṣ ṣā li ḥā ti u lā `i ka aṣ ḥā bul
# end_word 51
# wa iż a khaż nā mī ṡā qa ba nī is rā `ī la lā ta' b
# end_word 104
# ' bu dụ na il lall llā ha wa bil wā li dai ni iḥ sā naw
# end_word 150
#  sā naw wa żil qur bā wal ya tā mā wal ma sā kī ni wa
# end_word 196
# ī ni wa qụ lụ lin nā si ḥus naw wa a qī muṣ ṣa lā ta w
# end_word 58
# wa iż a khaż nā mī ṡā qa kum lā tas fi kụ na di mā `a kum
# end_word 104
# ā `a kum wa lā tukh ri jụ na an fu sa kum min di yā ri
# end_word 97
# ṡum ma an tum hā `u lā `i taq tu lụ na an fu sa kum wa tukh ri jụ na fa rī qam ming kum min di yā
# end_word 184
# n di yā ri him ta ẓā ha rụ na 'a lai him bil iṡ mi wal 'ud wān , wa iy ya` tụ kum u sā rā tu f
# end_word 276
# rā tu fā dụ hum wa hu wa mu ḥar ra mun 'a lai kum ikh rā ju hum , a fa tu` mi nụ na bi ba' ḍil ki t
# end_word 327
# il ki tā bi wa tak fu rụ na bi ba'ḍ , fa mā ja zā `u may y
# end_word 51
# u lā `i kal la żī nasy ta ra wul ḥa yā tad dun yā b
# end_word 89
# d dun yā bil ā khi ra ti fa lā yu khaf fa fu 'an
# end_word 56
# wa la qad ā tai nā mụ sal ki tā ba wa qaf fai nā mim ba'
# end_word 113
#  mim ba' di hī bir ru su li wa ā tai nā 'ī sab na mar ya mal bay
# end_word 169
#  mal bay yi nā ti wa ay yad nā hu bi rụ ḥil qu dus , a fa kul la
# end_word 201
# a kul la mā jā `a kum ra sụ lum bi mā lā
# end_word 39
# wa qā lụ qu lụ bu nā gulf , bal la 'a n
# end_word 65
# wa lam mā jā `a hum ki tā bum min 'in dil lā hi mu ṣad di qul li
# end_word 117
# i qul li mā ma 'a hum wa kā nụ ming qab lu yas taf ti ḥụ na '
# end_word 148
#  ḥụ na 'a lal la żī na ka fa rụ , fa la
# end_word 53
# bi` sa masy ta rau bi hī an fu sa hum ay yak fu rụ bi
# end_word 116
#  llā hu bag yan ay yu naz zi lall llā hu min faḍ
# end_word 162
# u min faḍ li hī 'a lā may ya syā `u min 'i bā dih , fa b
# end_word 36
# wa i żā qī la la hum ā mi nụ bi mā a
# end_word 96
# all llā hu qā lụ nu` mi nu bi mā un zi la 'a lai nā wa
# end_word 152
# ai nā wa yak fu rụ na bi mā wa rā `a hụ wa hu wal ḥaq qu mu ṣad
# end_word 180
#  mu ṣad di qal li mā ma 'a hum , qul
# end_word 76
# wa la qad jā `a kum mụ sā bil bay yi nā ti ṡum mat ta khaż tu mul 'ij la mim
# end_word 51
# wa iż a khaż nā mī ṡā qa kum wa ra fa' nā fau qa ku
# end_word 99
# au qa ku muṭ ṭụr , khu żụ mā ā tai nā kum bi quw wa tiw
# end_word 150
#  tiw was ma 'ụ , qā lụ sa mi' nā wa 'a ṣai nā wa usy ri
# end_word 184
# wa usy ri bụ fī qu lụ bi hi mul 'ij la bi ku
# end_word 43
# qul ing kā nat la ku mud dā rul ā khi ra tu
# end_word 98
# dall llā hi khā li ṣa tam min dụ nin nā si fa ta m
# end_word 52
# wa lay ya ta man nau hu a ba dam bi mā qad da mat ai
# end_word 62
# wa la ta ji dan na hum aḥ ra ṣan nā si 'a lā ḥa yāh , wa mi na
# end_word 123
# , wa mi nal la żī na asy ra kụ ya wad du a ḥa du hum lau yu 'am ma ru a
# end_word 146
# 'am ma ru al fa sa nah , wa mā hu
# end_word 62
# qul mang kā na 'a duw wal li jib rī la fa in na hụ naz za la h
# end_word 120
# la hụ 'a lā qal bi ka bi `iż nil lā hi mu ṣad di qal li mā bai
# end_word 58
# mang kā na 'a duw wal lil lā hi wa ma lā `i ka ti hī wa ru
# end_word 95
#  wa jib rī la wa mī kā la fa
# end_word 62
# wa la qad an zal nā i lai ka ā yā tim bay yi nāt , wa mā yak f
# end_word 66
# a wa kul la mā 'ā ha dụ 'ah dan na ba ża hụ fa rī qum min hum , ba
# end_word 53
# wa lam mā jā `a hum ra sụ lum min 'in dil lā hi mu ṣa
# end_word 99
# ā hi mu ṣad di qul li mā ma 'a hum na ba ża fa rī qum mi
# end_word 137
#  qum mi nal la żī na ụ tul ki tā ba ki tā bal
# end_word 119
# wat ta ba 'ụ mā tat lusy sya yā ṭī nu 'a lā mul ki su lai mān , wa mā ka fa ra su lai mā nu wa lā kin nasy sya yā ṭī na
# end_word 237
# yā ṭī na ka fa rụ yu 'al li mụ nan nā sas siḥ ra wa mā un zi la 'a lal ma la kai ni bi bā bi la hā rụ ta wa mā rụt , wa mā yu
# end_word 359
#  'al li mā ni min a ḥa din ḥat tā ya qụ lā in na mā naḥ nu fit na tun fa lā tak fur , fa ya ta 'al la mụ na min hu mā mā yu
# end_word 469
#  mā yu far ri qụ na bi hī bai nal mar 'i wa zau jih , wa mā hum bi ḍār rī na bi hī min a ḥa din il lā bi `iż nil lāh
# end_word 70
# wa lau an na hum ā ma nụ wat ta qau la ma ṡụ ba tum min 'in dil lā hi
# end_word 44
# yā ay yu hal la żī na ā ma nụ lā ta qụ lụ rā
# end_word 77
# a qụ lụ rā 'i nā wa qụ lun ẓur nā was ma 'ụ
# end_word 53
# mā ya wad dul la żī na ka fa rụ min ah lil ki tā bi w
# end_word 101
# tā bi wa lal musy ri kī na ay yu naz za la 'a lai kum m
# end_word 140
# hai rim mir rab bi kum , wall llā h
# end_word 53
# mā nan sakh min ā ya tin au nun si hā na` ti bi khai
# end_word 99
# miṡ li hā , a lam ta' lam an nal
# end_word 50
# am an nall llā ha la hụ mul kus sa mā w
# end_word 87
# s sa mā wā ti wal arḍ , wa mā la kum min dụ ni
# end_word 55
# am tu rī dụ na an tas `a lụ ra sụ la kum ka mā su `i la
# end_word 103
#  su `i la mụ sā ming qabl , wa may ya ta bad da lil kuf r
# end_word 53
# wad da ka ṡī rum min ah lil ki tā bi lau ya rud dụ na
# end_word 102
# rud dụ na kum mim ba' di ī mā ni kum kuf fā rā , ḥa sa dam
# end_word 148
#  ḥa sa dam min 'in di an fu si him mim ba' di mā ta bay
# end_word 193
# ul ḥaqq , fa' fụ waṣ fa ḥụ ḥat t
# end_word 55
# wa a qī muṣ ṣa lā ta wa ā tuz za kāh , wa mā tu qad di
# end_word 81
# tu qad di mụ li `an fu si kum min kh
# end_word 53
# wa qā lụ lay yad khu lal jan na ta il lā mang kā na h
# end_word 101
# kā na hụ dan au na ṣā rā , til ka a mā niy yu hum , qul
# end_word 53
# ba lā man as la ma waj ha hụ lil lā hi wa hu wa muḥ s
# end_word 99
# muḥ si nun fa la hū aj ru hụ 'in da rab bi hī wa lā
# end_word 60
# wa qā la til ya hụ du lai sa tin na ṣā rā 'a lā syai `iw wa
# end_word 112
# `iw wa qā la tin na ṣā rā lai sa til ya hụ du 'a lā syai `i
# end_word 152
# lā syai `iw wa hum yat lụ nal ki tāb , ka żā li ka
# end_word 204
#  żī na lā ya' la mụ na miṡ la qau li him ,
# end_word 38
# wa man aẓ la mu mim mam ma na 'a ma sā
# end_word 121
# yuż ka ra fī has mu hụ wa sa 'ā fī kha rā bi hā , u lā `i ka mā
# end_word 167
# `i ka mā kā na la hum ay yad khu lụ hā il lā khā `i fīn
# end_word 45
# wa lil lā hil masy ri qu wal mag ri bu fa ai
# end_word 85
#  ṡam ma waj hull llāh
# end_word 47
# a kha żall llā hu wa la dan sub ḥā n
# end_word 81
# sub ḥā nah , bal la hụ mā fis sa mā wā ti
# end_word 64
# ba dī 'us sa mā wā ti wal arḍ , wa i żā qa ḍā am ran fa in na mā
# end_word 47
# wa qā lal la żī na lā ya' la mụ na lau lā yu ka
# end_word 120
#  mu nall llā hu au ta` tī nā ā yah , ka żā li ka qā lal la żī na ming
# end_word 158
# ī na ming qab li him miṡ la qau li him , ta syā
# end_word 64
# in nā ar sal nā ka bil ḥaq qi ba syī raw wa na żī raw wa lā tus
# end_word 63
# wa lan tar ḍā 'ang kal ya hụ du wa lan na ṣā rā ḥat tā tat ta b
# end_word 127
#  mil la ta hum , qul in na hu dall llā hi hu wal hu dā , wa
# end_word 155
# u dā , wa la `i nit ta ba' ta ah wā `a
# end_word 57
# al la żī na ā tai nā hu mul ki tā ba yat lụ na hụ ḥaq qa
# end_word 106
# aq qa ti lā wa tih , u lā `i ka yu` mi nụ na bih , wa m
# end_word 45
# yā ba nī is rā `ī laż ku rụ ni' ma ti yal la
# end_word 77
# ti yal la tī an 'am tu 'a lai kum wa an nī
# end_word 57
# wat ta qụ yau mal lā taj zī naf sun 'an naf sin syai `aw
# end_word 102
# syai `aw wa lā yuq ba lu min hā 'ad luw wa lā tan fa '
# end_word 70
# wa i żib ta lā ib rā hī ma rab bu hụ bi ka li mā tin fa a tam ma hunn
# end_word 123
# m ma hunn , qā la in nī jā 'i lu ka lin nā si i mā mā , qā la w
# end_word 64
# wa iż ja 'al nal bai ta ma ṡā ba tal lin nā si wa am nā , wat ta
# end_word 118
# ā , wat ta khi żụ mim ma qā mi ib rā hī ma mu ṣal lā , wa 'a hid
# end_word 159
# wa 'a hid nā i lā ib rā hī ma wa is mā 'ī la an ṭa
# end_word 71
# wa iż qā la ib rā hī mu rab bij 'al hā żā ba la dan ā mi naw war zuq ah
# end_word 130
# ar zuq ah la hụ mi naṡ ṡa ma rā ti man ā ma na min hum bil lā hi wal
# end_word 179
#  wal yau mil ā khir , qā la wa mang ka fa ra fa u mat
# end_word 52
# wa iż yar fa 'u ib rā hī mul qa wā 'i da mi nal bai
# end_word 92
#  nal bai ti wa is mā 'īl , rab ba nā ta qab bal m
# end_word 71
# rab ba nā waj 'al nā mus li mai ni la ka wa min żur riy ya ti nā um ma
# end_word 121
# nā um ma tam mus li ma tal la ka wa a ri nā ma nā si ka nā
# end_word 69
# rab ba nā wab 'aṡ fī him ra sụ lam min hum yat lụ 'a lai him ā yā ti
# end_word 119
# ā yā ti ka wa yu 'al li mu hu mul ki tā ba wal ḥik ma ta w
# end_word 63
# wa may yar ga bu 'am mil la ti ib rā hī ma il lā man sa fi ha n
# end_word 110
# sa fi ha naf sah , wa la qa diṣ ṭa fai nā hu fid dun yā ,
# end_word 48
# iż qā la la hụ rab bu hū as lim qā la as lam tu
# end_word 54
# wa waṣ ṣā bi hā ib rā hī mu ba nī hi wa ya' qụb , yā b
# end_word 102
# a niy ya in nall llā haṣ ṭa fā la ku mud dī na f
# end_word 59
# am kun tum syu ha dā `a iż ḥa ḍa ra ya' qụ bal mau tu iż qā
# end_word 114
# u tu iż qā la li ba nī hi mā ta' bu dụ na mim ba' dī , qā lụ na'
# end_word 162
#  na' bu du i lā ha ka wa i lā ha ā bā `i ka ib rā hī
# end_word 55
# til ka um ma tung qad kha lat , la hā mā ka sa bat wa l
# end_word 84
# t wa la kum mā ka sab tum , wa lā t
# end_word 40
# wa qā lụ kụ nụ hụ dan au na ṣā rā tah ta
# end_word 81
# ā tah ta dụ , qul bal mil la ta ib rā hī ma ḥa nī
# end_word 51
# qụ lū ā man nā bil lā hi wa mā un zi la i lai nā wa
# end_word 95
#  lai nā wa mā un zi la i lā ib rā hī ma wa is mā 'ī la
# end_word 143
# 'ī la wa is ḥā qa wa ya' qụ ba wal as bā ṭi wa mā ụ t
# end_word 187
# a mā ụ ti ya mụ sā wa 'ī sā wa mā ụ ti yan na biy yụ
# end_word 65
# fa in ā ma nụ bi miṡ li mā ā man tum bi hī fa qa dih ta dau , wa
# end_word 96
# au , wa in ta wal lau fa in na mā hum f
# end_word 62
# aḥ sa nu mi nall llā hi ṣib ga taw w
# end_word 54
# qul a tu ḥāj jụ na nā fil lā hi wa hu wa rab bu nā wa
# end_word 97
#  nā wa rab bu kum , wa la nā a' mā lu nā wa la kum
# end_word 50
# am ta qụ lụ na in na ib rā hī ma wa is mā 'ī la wa
# end_word 96
# a wa is ḥā qa wa ya' qụ ba wal as bā ṭa kā nụ hụ d
# end_word 145
# kā nụ hụ dan au na ṣā rā , qul a an tum a' la mu a mil lāh
# end_word 184
# n aẓ la mu mim mang ka ta ma sya
# end_word 55
# til ka um ma tung qad kha lat , la hā mā ka sa bat wa l
# end_word 84
# at wa la kum mā ka sab tum , wa lā t
# end_word 37
# sa ya qụ lus su fa hā `u mi nan nā si
# end_word 103
#  hum 'ang qib la ti hi mul la tī kā nụ 'a lai hā , qul
# end_word 132
# ai hā , qul lil lā hil masy ri qu wal ma
# end_word 79
# wa ka żā li ka ja 'al nā kum um ma taw wa sa ṭal li ta kụ nụ syu ha dā `a 'a la
# end_word 155
#  `a 'a lan nā si wa ya kụ nar ra sụ lu 'a lai kum sya hī dā , wa mā ja 'al nal qib la
# end_word 229
# l qib la tal la tī kun ta 'a lai hā il lā li na' la ma may yat ta bi 'ur ra sụ la
# end_word 278
# g qa li bu 'a lā 'a qi baīh , wa ing k
# end_word 69
# qad na rā ta qal lu ba waj hi ka fis sa mā` , fa la nu wal li yan na
# end_word 122
# i yan na ka qib la tan tar ḍā hā fa wal li waj ha ka syaṭ ral
# end_word 181
#  ral mas ji dil ḥa rām , wa ḥai ṡu mā kun tum fa wal lụ wu jụ ha
# end_word 208
# wu jụ ha kum syaṭ rah , wa in nal l
# end_word 54
# wa la `in a tai tal la żī na ụ tul ki tā ba bi kul li
# end_word 111
#  kul li ā ya tim mā ta bi 'ụ qib la tak , wa mā an ta bi tā bi 'i
# end_word 169
#  bi 'ing qib la ta hum , wa mā ba' ḍu hum bi tā bi 'ing qib la t
# end_word 198
# g qib la ta ba'ḍ , wa la `i nit ta ba'
# end_word 63
# al la żī na ā tai nā hu mul ki tā ba ya' ri fụ na hụ ka mā ya'
# end_word 108
# mā ya' ri fụ na ab nā `a hum , wa in na fa rī qam mi
# end_word 43
# al ḥaq qu mir rab bi ka fa lā ta kụ nan na
# end_word 64
# wa li kul liw wij ha tun hu wa mu wal lī hā fas ta bi qul khai r
# end_word 119
# ya` ti bi ku mull llā hu ja mī '
# end_word 60
# wa min ḥai ṡu kha raj ta fa wal li waj ha ka syaṭ ral mas ji
# end_word 112
# na hụ lal ḥaq qu mir rab bik , w
# end_word 60
# wa min ḥai ṡu kha raj ta fa wal li waj ha ka syaṭ ral mas ji
# end_word 121
# as ji dil ḥa rām , wa ḥai ṡu mā kun tum fa wal lụ wu jụ ha kum sya
# end_word 178
# um syaṭ ra hụ li `al lā ya kụ na lin nā si 'a lai kum ḥuj ja tu
# end_word 222
# j ja tun il lal la żī na ẓa la mụ min hum fa lā tak
# end_word 47
# ka mā ar sal nā fī kum ra sụ lam ming kum yat l
# end_word 95
# kum yat lụ 'a lai kum ā yā ti nā wa yu zak kī kum wa yu '
# end_word 127
# a yu 'al li mu ku mul ki tā ba wal ḥik
# end_word 39
# faż ku rụ nī aż kur kum wasy ku rụ lī w
# end_word 55
# yā ay yu hal la żī na ā ma nus ta 'ī nụ biṣ ṣab ri waṣ
# end_word 69
# wa lā ta qụ lụ li may yuq ta lu fī sa bī lil lā hi am wāt , bal aḥ yā
# end_word 60
# wa la nab lu wan na kum bi syai `im mi nal khau fi wal jụ 'i
# end_word 102
# wal jụ 'i wa naq ṣim mi nal am wā li wal an fu si w
# end_word 62
# al la żī na i żā a ṣā bat hum mu ṣī bah , qā lū in nā lil lā h
# end_word 66
# u lā `i ka 'a lai him ṣa la wā tum mir rab bi him wa raḥ mah , wa
# end_word 50
# in naṣ ṣa fā wal mar wa ta min sya 'ā `i ril lāh ,
# end_word 102
# ril lāh , fa man ḥaj jal bai ta a wi' ta ma ra fa lā ju nā ḥa
# end_word 132
#  ju nā ḥa 'a lai hi ay yaṭ ṭaw wa fa bi
# end_word 48
# in nal la żī na yak tu mụ na mā an zal nā mi nal
# end_word 97
# ā mi nal bay yi nā ti wal hu dā mim ba' di mā bay yan nā
# end_word 132
# in nā si fil ki tā bi u lā `i k
# end_word 45
# il lal la żī na tā bụ wa aṣ la ḥụ wa bay ya n
# end_word 74
#  bay ya nụ fa u lā `i ka a tụ bu 'a la
# end_word 53
# in nal la żī na ka fa rụ wa mā tụ wa hum kuf fā run u
# end_word 92
# ā `i ka 'a lai him la' na tull llā hi
# end_word 55
# khā li dī na fī hā , lā yu khaf fa fu 'an hu mul 'a żā
# end_word 51
# wa i lā hu kum i lā huw wā ḥid , lā i lā ha il lā h
# end_word 68
# in na fī khal qis sa mā wā ti wal ar ḍi wakh ti lā fil lai li wan na
# end_word 112
#  wan na hā ri wal ful kil la tī taj rī fil baḥ ri b
# end_word 206
# nā sa wa mā an za lall llā hu mi nas sa mā `i mim mā `in fa aḥ yā bi hil ar ḍa
# end_word 267
# hil ar ḍa ba' da mau ti hā wa baṡ ṡa fī hā ming kul li dāb ba tiw wa t
# end_word 59
# wa mi nan nā si may yat ta khi żu min dụ nil lā hi an dā da
# end_word 110
#  an dā day yu ḥib bụ na hum ka ḥub bil lāh , wal la żī na ā
# end_word 156
#  na ā ma nū a syad du ḥub bal lil lā hi wa lau ya ra
# end_word 178
#  lau ya ral la żī na ẓa la mū iż
# end_word 49
# iż ta bar ra `al la żī nat tu bi 'ụ mi nal la żī
# end_word 82
# al la żī nat ta ba 'ụ wa ra `a wul 'a żā b
# end_word 56
# wa qā lal la żī nat ta ba 'ụ lau an na la nā kar ra tan
# end_word 101
# r ra tan fa na ta bar ra `a min hum , ka mā ta bar ra
# end_word 154
# in nā , ka żā li ka yu rī hi mull llā hu a' mā la
# end_word 51
# yā ay yu han nā su ku lụ mim mā fil ar ḍi ḥa lā lan
# end_word 100
# a lā lan ṭay yi baw wa lā tat ta bi 'ụ khu ṭu wā tisy sya
# end_word 55
# in na mā ya` mu ru kum bis sū `i wal faḥ syā `i wa an t
# end_word 37
# wa i żā qī la la hu mut ta bi 'ụ mā a
# end_word 91
# an za lall llā hu qā lụ bal nat ta bi 'u mā al fai nā '
# end_word 125
#  fai nā 'a lai hi ā bā `a nā , a wa lau kā
# end_word 58
# wa ma ṡa lul la żī na ka fa rụ ka ma ṡa lil la żī yan 'i q
# end_word 107
#  yan 'i qu bi mā lā yas ma 'u il lā du 'ā `aw wa ni dā `ā
# end_word 53
# yā ay yu hal la żī na ā ma nụ ku lụ min ṭay yi bā ti
# end_word 86
#  yi bā ti mā ra zaq nā kum wasy ku rụ lil l
# end_word 55
# in na mā ḥar ra ma 'a lai ku mul mai ta ta wad da ma wa
# end_word 108
# a ma wa laḥ mal khin zī ri wa mā u hil la bi hī li gai ril l
# end_word 136
# ai ril lāh , fa ma niḍ ṭur ra gai ra
# end_word 35
# in nal la żī na yak tu mụ na mā an
# end_word 97
# l llā hu mi nal ki tā bi wa yasy ta rụ na bi hī ṡa ma na
# end_word 139
# a ma nang qa lī lan u lā `i ka mā ya` ku lụ na fī
# end_word 186
#  bu ṭụ ni him il lan nā ra wa lā yu kal li mu h
# end_word 52
# u lā `i kal la żī nasy ta ra wuḍ ḍa lā la ta bil hu
# end_word 80
# ta bil hu dā wal 'a żā ba bil mag fi r
# end_word 56
# i `an nall llā ha naz za lal ki tā ba bil ḥaqq
# end_word 89
#  bil ḥaqq , wa in nal la żī nakh ta la fụ
# end_word 101
# lai sal bir ra an tu wal lụ wu jụ ha kum qi ba lal masy ri qi wal mag ri bi wa lā kin nal bir ra man
# end_word 201
#  ma na bil lā hi wal yau mil ā khi ri wal ma lā `i ka ti wal ki tā bi wan na biy yīn , wa ā tal mā
# end_word 289
# tal mā la 'a lā ḥub bi hī ża wil qur bā wal ya tā mā wal ma sā kī na wab nas sa bī li was sā `i
# end_word 359
#  was sā `i lī na wa fir ri qāb , wa a qā maṣ ṣa lā ta wa ā taz za kāh , wal mụ f
# end_word 59
# yā ay yu hal la żī na ā ma nụ ku ti ba 'a lai ku mul qi ṣā
# end_word 122
# ṣā ṣu fil qat lā , al ḥur ru bil ḥur ri wal 'ab du bil 'ab di wal
# end_word 190
# i wal un ṡā bil un ṡā , fa man 'u fi ya la hụ min a khī hi syai `un fat ti
# end_word 245
# un fat ti bā 'um bil ma' rụ fi wa a dā `un i lai hi bi `iḥ sān ,
# end_word 53
# wa la kum fil qi ṣā ṣi ḥa yā tuy yā u lil al bā bi la
# end_word 66
# ku ti ba 'a lai kum i żā ḥa ḍa ra a ḥa da ku mul mau tu in ta ra k
# end_word 116
# ta ra ka khai ra nil wa ṣiy ya tu lil wā li dai ni wal aq
# end_word 50
# fa mam bad da la hụ ba' da mā sa mi 'a hụ fa in na
# end_word 78
# ụ fa in na mā iṡ mu hụ 'a lal la żī na
# end_word 52
# fa man khā fa mim mụ ṣin ja na fan au iṡ man fa aṣ l
# end_word 74
# an fa aṣ la ḥa bai na hum fa lā
# end_word 51
# yā ay yu hal la żī na ā ma nụ ku ti ba 'a lai ku mu
# end_word 93
#  lai ku muṣ ṣi yā mu ka mā ku ti ba 'a lal la żī na
# end_word 49
# ay yā mam ma' dụ dāt , fa mang kā na ming kum ma
# end_word 105
#  kum ma rī ḍan au 'a lā sa fa rin fa 'id da tum min ay yā min u
# end_word 165
# ā min u khar , wa 'a lal la żī na yu ṭī qụ na hụ fid ya tun ṭa 'ā mu
# end_word 200
#  ṭa 'ā mu mis kīn , fa man ta ṭaw wa 'a khai
# end_word 80
# syah ru ra ma ḍā nal la żī un zi la fī hil qur `ā nu hu dal lin nā si wa bay yi
# end_word 161
# y yi nā tim mi nal hu dā wal fur qān , fa man sya hi da ming ku musy syah ra fal ya ṣu
# end_word 240
#  na ma rī ḍan au 'a lā sa fa rin fa 'id da tum min ay yā min u
# end_word 294
# rī dull llā hu bi ku mul yus ra wa lā yu rī
# end_word 60
# wa i żā sa `a la ka 'i bā dī 'an nī fa in nī qa rīb , u jī b
# end_word 107
#  , u jī bu da' wa tad dā 'i i żā da 'ā ni fal yas ta jī
# end_word 96
# u ḥil la la kum lai la taṣ ṣi yā mir ra fa ṡu i lā ni sā `i kum , hun na li bā sul la kum wa an
# end_word 196
# unn , 'a li mall llā hu an na kum kun tum takh tā nụ na an fu sa kum fa tā ba 'a l
# end_word 339
# ā na bā syi rụ hun na wab ta gụ mā ka ta ball llā hu la kum , wa ku lụ wasy ra bụ ḥat tā ya ta bay ya na la ku m
# end_word 407
#  mi nal khai ṭil as wa di mi nal fajr , ṡum ma a
# end_word 46
# wa lā ta` ku lū am wā la kum bai na kum bil bā
# end_word 88
#  bil bā ṭi li wa tud lụ bi hā i lal ḥuk kā mi li
# end_word 111
#  kā mi li ta` ku lụ fa rī qam min
# end_word 50
# yas `a lụ na ka 'a nil a hil lah , qul hi ya ma wā
# end_word 99
#  ma wā qī tu lin nā si wal ḥajj , wa lai sal bir ru bi
# end_word 148
#  ru bi `an ta` tul bu yụ ta min ẓu hụ ri hā wa lā kin na
# end_word 175
# al bir ra ma nit ta qā , wa`
# end_word 45
# wa qā ti lụ fī sa bī lil lā hil la żī na yu q
# end_word 82
# a kum wa lā ta' ta dụ , in n
# end_word 52
# waq tu lụ hum ḥai ṡu ṡa qif tu mụ hum wa akh ri jụ h
# end_word 100
# kh ri jụ hum min ḥai ṡu akh ra jụ kum wal fit na tu a syad
# end_word 154
# a syad du mi nal qatl , wa lā tu qā ti lụ hum 'in dal mas ji
# end_word 186
# mas ji dil ḥa rā mi ḥat tā yu qā ti lụ
# end_word 24
# fa i nin ta hau fa in na
# end_word 55
# wa qā ti lụ hum ḥat tā lā ta kụ na fit na tuw wa ya kụ
# end_word 90
# a ya kụ nad dī nu lil lāh , fa i nin ta hau
# end_word 57
# asy syah rul ḥa rā mu bisy syah ril ḥa rā mi wal ḥu ru mā
# end_word 110
# ḥu ru mā tu qi ṣāṣ , fa ma ni' ta dā 'a lai kum fa' ta dụ 'a
# end_word 137
#  lai hi bi miṡ li ma' ta dā
# end_word 46
# wa an fi qụ fī sa bī lil lā hi wa lā tul qụ bi
# end_word 73
# ul qụ bi `ai dī kum i lat tah lu ka
# end_word 113
# wa a tim mul ḥaj ja wal 'um ra ta lil lāh , fa in uḥ ṣir tum fa mas tai sa ra mi nal hady , wa lā taḥ li qụ ru `ụ
# end_word 236
#  sa kum ḥat tā yab lu gal had yu ma ḥil lah , fa mang kā na ming kum ma rī ḍan au bi hī a żam mir ra` si hī fa fid ya tum m
# end_word 356
# tum min ṣi yā min au ṣa da qa tin au nu suk , fa i żā a min tum , fa man ta mat ta 'a bil 'um ra ti i lal ḥaj ji fa mas tai s
# end_word 413
# as tai sa ra mi nal hady , fa mal lam ya jid fa ṣi yā mu ṡa lā ṡa
# end_word 53
# al ḥaj ju asy hu rum ma' lụ māt , fa man fa ra ḍa fī
# end_word 100
# a ḍa fī hin nal ḥaj ja fa lā ra fa ṡa wa lā fu sụ qa wa
# end_word 152
#  fil ḥajj , wa mā taf 'a lụ min khai riy
# end_word 176
# hai riy ya' lam hull llāh , wa
# end_word 62
# lai sa 'a lai kum ju nā ḥun an tab ta gụ faḍ lam mir rab bi ku
# end_word 117
#  faḍ tum min 'a ra fā tin faż ku rull llā
# end_word 162
# ll llā ha 'in dal masy 'a ril ḥa rā mi waż ku rụ hu
# end_word 45
# ṡum ma a fī ḍụ min ḥai ṡu a fā ḍan nā su was
# end_word 38
# fa i żā qa ḍai tum ma na si ka kum faż
# end_word 103
# ull llā ha ka żik ri kum ā bā `a kum au a syad da żik rā , f
# end_word 139
# żik rā , fa mi nan nā si may ya qụ lu rab ba n
# end_word 48
# wa min hum may ya qụ lu rab ba nā ā ti nā fid du
# end_word 84
#  fid dun yā ḥa sa na taw wa fil ā khi ra ti
# end_word 40
# u lā `i ka la hum na ṣī bum mim mā ka sa
# end_word 61
# ku rull llā ha fī ay yā mim ma' dụ dāt , fa man ta 'aj ja
# end_word 117
#  ta 'aj ja la fī yau mai ni fa lā iṡ ma 'a laīh , wa man ta `akh k
# end_word 157
# a ra fa lā iṡ ma 'a lai hi li ma nit ta
# end_word 48
# wa mi nan nā si may yu' ji bu ka qau lu hụ fil ḥ
# end_word 96
#  tid dun yā wa yusy hi dull llā ha 'a lā mā
# end_word 50
# wa i żā ta wal lā sa 'ā fil ar ḍi li yuf si da fī
# end_word 83
# h li kal ḥar ṡa wan nasl
# end_word 45
# wa i żā qī la la hut ta qil lā ha a kha żat h
# end_word 80
# a żat hul 'iz za tu bil iṡ mi fa ḥas bu hụ
# end_word 55
# wa mi nan nā si may yasy rī naf sa hub ti gā `a mar ḍā
# end_word 51
# yā ay yu hal la żī na ā ma nud khu lụ fis sil mi kā
# end_word 98
#  sil mi kāf fa taw wa lā tat ta bi 'ụ khu ṭu wā tisy syai
# end_word 59
# fa in za lal tum mim ba' di mā jā `at ku mul bay yi nā tu f
# end_word 36
# hal yan ẓu rụ na il lā ay ya` ti ya
# end_word 94
# fī ẓu la lim mi nal ga mā mi wal ma lā `i k
# end_word 63
# sal ba nī is rā `ī la kam ā tai nā hum min ā ya tim bay yi nah
# end_word 102
#  , wa may yu bad dil ni' ma tall llā hi
# end_word 49
# zuy yi na lil la żī na ka fa rul ḥa yā tud dun yā
# end_word 97
#  dun yā wa yas kha rụ na mi nal la żī na ā ma nụ , wal
# end_word 139
# żī nat ta qau fau qa hum yau mal qi yā
# end_word 92
# dah , fa ba 'a ṡall llā hun na biy yī na mu basy syi rī na wa m
# end_word 171
# rī na wa mun żi rī na wa an za la ma 'a hu mul ki tā ba bil ḥaq qi li yaḥ ku ma bai nan n
# end_word 228
# i nan nā si fī makh ta la fụ fīh , wa makh ta la fa fī hi il lal
# end_word 317
# bay yi nā tu bag yam bai na hum , fa ha dal
# end_word 52
# am ḥa sib tum an tad khu lul jan na ta wa lam mā ya`
# end_word 105
#  mā ya` ti kum ma ṡa lul la żī na kha lau ming qab li kum ,
# end_word 154
#  kum , mas sat hu mul ba` sā `u waḍ ḍar rā `u wa zul zi
# end_word 185
#  ḥat tā ya qụ lar ra sụ lu wa
# end_word 52
# yas `a lụ na ka mā żā yun fi qụn , qul mā an faq tum
# end_word 97
# an faq tum ming kai rin fa lil wā li dai ni wal aq ra b
# end_word 138
#  ra bī na wal ya tā mā wal ma sā kī ni wab nis
# end_word 55
# ku ti ba 'a lai ku mul qi tā lu wa hu wa kur hul la kum
# end_word 114
# m , wa 'a sā an tak ra hụ syai `aw wa hu wa khai rul la kum
# end_word 155
#  sā an tu ḥib bụ syai `aw wa hu wa
# end_word 110
# yas `a lụ na ka 'a nisy syah ril ḥa rā mi qi tā lin fīh , qul qi tā lun fī hi ka bīr , wa ṣad dun 'an sa bī li
# end_word 200
# as ji dil ḥa rā mi wa ikh rā ju ah li hī min hu ak ba ru 'in
# end_word 293
# u 'in dall llāh , wal fit na tu ak ba ru mi nal qatl , wa lā ya zā lụ na yu qā ti lụ na kum ḥat tā
# end_word 365
#  tā ya rud dụ kum 'an dī ni kum i nis ta ṭā 'ụ , wa may yar ta did ming kum
# end_word 52
# in nal la żī na ā ma nụ wal la żī na hā ja rụ wa jā
# end_word 80
#  ja rụ wa jā ha dụ fī sa bī lil lā hi u l
# end_word 50
# yas `a lụ na ka 'a nil kham ri wal mai sir , qul f
# end_word 102
#  , qul fī hi mā iṡ mung ka bī ruw wa ma na fi 'u lin nā si w
# end_word 156
# nā si wa iṡ mu hu mā ak ba ru min naf 'i hi mā , wa yas `a lụ
# end_word 194
#  `a lụ na ka mā żā yun fi qụn , qu lil 'afw
# end_word 59
# fid dun yā wal ā khi rah , wa yas `a lụ na ka 'a nil ya tā
# end_word 103
# a tā mā , qul iṣ lā ḥul la hum khaīr , wa in tu k
# end_word 171
# ll llā hu ya' la mul muf si da mi
# end_word 87
# wa lā tang ki ḥul musy ri kā ti ḥat tā yu` minn , wa la `a ma tum mu` mi na tun khai ru
# end_word 157
# n khai rum mim musy ri ka tiw wa lau a' ja bat kum , wa lā tung ki ḥul musy ri
# end_word 213
#  ri kī na ḥat tā yu` mi nụ , wa la 'ab dum mu` mi nun khai r
# end_word 297
# i kiw wa lau a' ja ba kum , u lā `i ka yad 'ụ na i lan nā ri wall llā h
# end_word 47
# wa yas `a lụ na ka 'a nil ma ḥīḍ , qul hu wa a
# end_word 92
# hu wa a żan fa' ta zi lun ni sā `a fil ma ḥī ḍi wa lā
# end_word 138
#  ḍi wa lā taq ra bụ hun na ḥat tā yaṭ hurn , fa i żā ta
# end_word 188
# ṭah har na fa` tụ hun na min ḥai ṡu a ma ra ku mu
# end_word 49
# ni sā `u kum ḥar ṡul la kum fa` tụ ḥar ṡa kum an
# end_word 80
#  kum an nā syi` tum wa qad di mụ li `an
# end_word 122
# si kum , wat ta qull llā ha wa' la mū
# end_word 58
# j 'a lull llā ha 'ur ḍa tal li `ai mā ni kum an ta
# end_word 84
# m an ta bar rụ wa tat ta qụ wa tu
# end_word 63
#  żu ku mull llā hu bil lag wi fī ai mā ni kum wa lā
# end_word 90
# um wa lā kiy yu `ā khi żu kum bi mā
# end_word 50
# lil la żī na yu` lụ na min ni sā `i him ta rab bu
# end_word 73
# ta rab bu ṣu ar ba 'a ti asy hur
# end_word 30
# wa in 'a za muṭ ṭa lā qa fa in
# end_word 86
# wal mu ṭal la qā tu ya ta rab baṣ na bi `an fu si hin na ṡa lā ṡa ta qu rū` , wa lā ya
# end_word 164
# il lu la hun na ay yak tum na mā kha la qall llā hu fī ar ḥā mi hin na ing k
# end_word 247
# ing kun na yu` min na bil lā hi wal yau mil ā khir , wa bu 'ụ la tu hun na a ḥaq qu bi r
# end_word 281
# aq qu bi rad di hin na fī żā li ka in a rā d
# end_word 78
# aṭ ṭa lā qu mar ra tā ni fa im sā kum bi ma' rụ fin au tas rī ḥum bi `iḥ sān ,
# end_word 142
#  `iḥ sān , wa lā ya ḥil lu la kum an ta` khu żụ mim mā ā tai tu mụ hun na
# end_word 219
#  fā al lā yu qī mā ḥu dụ dall llāh , fa in khif tum a
# end_word 268
#  al lā yu qī mā ḥu dụ dall llā hi fa lā ju nā ḥa 'a
# end_word 68
# fa in ṭal la qa hā fa lā ta ḥil lu la hụ mim ba' du ḥat tā tang ki ḥ
# end_word 125
# ng ki ḥa zau jan gai rah , fa in ṭal la qa hā fa lā ju nā ḥa 'a
# end_word 181
# rā ja 'ā in ẓan nā ay yu qī mā ḥu dụ
# end_word 92
# wa i żā ṭal laq tu mun ni sā `a fa ba lag na a ja la hun na fa am si kụ hun na bi ma' rụ fin
# end_word 172
# ' rụ fin au sar ri ḥụ hun na bi ma' rụf , wa lā tum si kụ hun na ḍi rā ral li ta' ta dụ
# end_word 255
#  fa qad ẓa la ma naf sah , wa lā tat ta khi żū ā yā til lā
# end_word 318
# l llā hi 'a lai kum wa mā an
# end_word 62
# wa i żā ṭal laq tu mun ni sā `a fa ba lag na a ja la hun na fa
# end_word 116
# un na fa lā ta' ḍu lụ hun na ay yang kiḥ na az wā ja hun na i
# end_word 176
#  na i żā ta rā ḍau bai na hum bil ma' rụf , żā li ka yụ 'a ẓu bi h
# end_word 224
# ing kum yu` mi nu bil lā hi wal ya
# end_word 122
# wal wā li dā tu yur ḍi' na au lā da hun na ḥau lai ni kā mi lai ni li man a rā da ay yu tim mar ra ḍā 'ah , wa 'a lal mau
# end_word 237
# al mau lụ di la hụ riz qu hun na wa kis wa tu hun na bil ma' rụf , lā tu kal la fu naf sun il lā wus 'a hā , lā tu ḍār ra
# end_word 343
# ār ra wā li da tum bi wa la di hā wa lā mau lụ dul la hụ bi wa la di hī wa 'a lal wā ri ṡi miṡ lu żā lik , fa in
# end_word 394
# , fa in a rā dā fi ṣā lan 'an ta rā ḍim min hu mā wa ta sy
# end_word 62
# wal la żī na yu ta waf fau na ming kum wa ya ża rụ na az wā ja
# end_word 121
# z wā jay ya ta rab baṣ na bi `an fu si hin na ar ba 'a ta asy hu r
# end_word 174
# asy hu riw wa 'asy rā , fa i żā ba lag na a ja la hun na fa l
# end_word 198
#  fa lā ju nā ḥa 'a lai kum fī
# end_word 78
# wa lā ju nā ḥa 'a lai kum fī mā 'ar raḍ tum bi hī min khiṭ ba tin ni sā `i au
# end_word 155
# ak nan tum fī an fu si kum , 'a li mall llā hu an na kum sa taż ku rụ na hun
# end_word 228
# a hun na wa lā kil lā tu wā 'i dụ hun na sir ran il lā an ta qụ lụ qau lam ma'
# end_word 281
# ma' rụ fā , wa lā ta' zi mụ 'uq da tan ni kā ḥi ḥat tā ya
# end_word 66
# lā ju nā ḥa 'a lai kum in ṭal laq tu mun ni sā `a mā lam ta mas sụ
# end_word 124
#  ta mas sụ hun na au taf ri ḍụ la hun na fa rī ḍa taw wa mat ti 'ụ h
# end_word 168
#  'ụ hun na 'a lal mụ si 'i qa da ru hụ wa 'a lal
# end_word 67
# wa in ṭal laq tu mụ hun na ming qab li an ta mas sụ hun na wa qad f
# end_word 119
# a wa qad fa raḍ tum la hun na fa rī ḍa tan fa niṣ fu mā fa raḍ
# end_word 173
# mā fa raḍ tum il lā ay ya' fụ na au ya' fu wal la żī bi ya di h
# end_word 216
#  kāḥ , wa an ta' fū aq ra bu
# end_word 54
# ḥā fi ẓụ 'a laṣ ṣa la wā ti waṣ ṣa lā til wus ṭā wa qụ
# end_word 53
# fa in khif tum fa ri jā lan au ruk bā nā , fa i żā a
# end_word 89
# i żā a min tum faż ku rull llā ha ka mā 'al
# end_word 59
# wal la żī na yu ta waf fau na ming kum wa ya ża rụ na az wā
# end_word 101
# ụ na az wā jaw wa ṣiy ya tal li `az wā ji him ma tā
# end_word 153
#  ma tā 'an i lal ḥau li gai ra ikh rāj , fa in kha raj na f
# end_word 180
# ju nā ḥa 'a lai kum fī
# end_word 52
# wa lil mu ṭal la qā ti ma tā 'um bil ma' rụf , ḥaq q
# end_word 54
#  bay yi null llā hu la kum ā yā ti hī la
# end_word 59
# a lam ta ra i lal la żī na kha ra jụ min di yā ri him wa hu
# end_word 108
#  ḥa ża ral mau ti fa qā la la hu mull l
# end_word 158
# ull llā hu mụ tụ , ṡum ma aḥ yā hum , in nall llā ha la
# end_word 39
# wa qā ti lụ fī sa bī lil lā hi wa' la m
# end_word 62
# yuq ri ḍull llā ha qar ḍan ḥa sa nan fa yu ḍā 'i
# end_word 110
#  la hū aḍ 'ā fang ka ṡī rah , wall llā hu
# end_word 76
# a lam ta ra i lal ma la `i mim ba nī is rā `ī la mim ba' di mụ sā , iż qā lụ
# end_word 158
#  iż qā lụ li na biy yil la hu mub 'aṡ la nā ma li kan nu qā til fī sa bī lil lāh , qā la ha
# end_word 240
#  hal 'a sai tum ing ku ti ba 'a lai ku mul qi tā lu al lā tu qā ti lụ , qā lụ wa mā l
# end_word 292
# lụ wa mā la nā al lā nu qā ti la fī sa bī lil lā hi wa qad ukh
# end_word 70
#  yu hum in nall llā ha qad ba 'a ṡa la kum ṭā lụ
# end_word 137
# ā lụ ta ma li kā , qā lū an nā ya kụ nu la hul mul ku 'a lai nā wa naḥ
# end_word 198
# u bil mul ki min hu wa lam yu` ta sa 'a tam mi nal
# end_word 244
#  qā la in nall llā haṣ ṭa fā hu 'a lai ku
# end_word 55
# wa qā la la hum na biy yu hum in na ā ya ta mul ki hī a
# end_word 101
# ul ki hī ay ya` ti ya ku mut tā bụ tu fī hi sa kī na tum
# end_word 149
# ī na tum mir rab bi kum wa ba qiy ya tum mim mā ta ra ka
# end_word 185
# ta ra ka ā lu mụ sā wa ā lu hā rụ na taḥ mi
# end_word 99
# u nụ di qā la in nall llā ha mub ta lī kum bi na har , fa man sya
# end_word 202
# i ba min hu fa lai sa min nī , wa mal lam yaṭ 'am hu fa in na hụ min nī il lā ma nig ta ra fa gur fa t
# end_word 290
#  gur fa tam bi ya dih , fa sya ri bụ min hu il lā qa lī lam min hum , fa lam mā jā wa za hụ hu wa
# end_word 370
# al la żī na ā ma nụ ma 'a hụ qā lụ lā ṭā qa ta la nal yau ma bi jā lụ ta wa ju
# end_word 56
# wa lam mā ba ra zụ li jā lụ ta wa ju nụ di hī qā lụ rab
# end_word 102
# lụ rab ba nā af rig 'a lai nā ṣab raw wa ṡab bit aq d
# end_word 57
# fa ha za mụ hum bi `iż nil lāh , wa qa ta la dā wụ du jā
# end_word 115
# ta wa ā tā hull llā hul mul ka wal ḥik ma ta wa 'al la
# end_word 167
# m mā ya syā` , wa lau lā daf 'ull llā hin nā
# end_word 62
# ā yā tull llā hi nat lụ hā 'a lai ka bil ḥaqq , wa in n
# end_word 61
# til kar ru su lu faḍ ḍal nā ba' ḍa hum 'a lā ba'ḍ , min hum m
# end_word 158
#  hu wa ra fa 'a ba' ḍa hum da ra jāt , wa ā tai nā 'ī sab na mar ya mal bay yi
# end_word 249
# i wa ay yad nā hu bi rụ ḥil qu dus , wa lau syā `all llā hu maq ta ta lal la żī na mim
# end_word 281
# ī na mim ba' di him mim ba' di mā jā `at
# end_word 46
# yā ay yu hal la żī na ā ma nū an fi qụ mim mā
# end_word 93
# qụ mim mā ra zaq nā kum ming qab li ay ya` ti ya yau mul
# end_word 126
# yau mul lā bai 'un fī hi wa lā khul la tu
# end_word 76
# all llā hu lā i lā ha il lā huw , al ḥay yul qay yụm , lā ta` khu żu hụ si n
# end_word 147
# ụ si na tuw wa lā na `ụm , la hụ mā fis sa mā wā ti wa mā fil arḍ , man żal l
# end_word 229
# żal la żī yasy fa 'u 'in da hū il lā bi `iż nih , ya' la mu mā bai na ai dī him wa mā k
# end_word 285
# a mā khal fa hum , wa lā yu ḥī ṭụ na bi syai `im min 'il mi hī
# end_word 52
# lā ik rā ha fid dīn , qat ta bay ya nar rusy du mi n
# end_word 105
#  du mi nal gayy , fa may yak fur biṭ ṭā gụ ti wa yu` mim bil
# end_word 132
#  mim bil lā hi fa qa dis tam sa ka b
# end_word 64
# all llā hu wa liy yul la żī na ā ma nụ yukh ri ju hum mi naẓ ẓu
# end_word 120
# mi naẓ ẓu lu mā ti i lan nụr , wal la żī na ka fa rū au li yā `u h
# end_word 160
# li yā `u hu muṭ ṭā gụ tu yukh ri jụ na hum mi nan
# end_word 52
# a lam ta ra i lal la żī ḥāj ja ib rā hī ma fī rab bi
# end_word 117
# hī an ā tā hull llā hul mulk , iż qā la ib rā hī mu rab bi yal l
# end_word 183
# a yu mī tu qā la a na uḥ yī wa u mīt , qā la ib rā hī
# end_word 217
# b rā hī mu fa in nall llā ha ya` tī bisy
# end_word 107
# au kal la żī mar ra 'a lā qar ya tiw wa hi ya khā wi ya tun 'a lā 'u rụ syi hā , qā la an nā yuḥ yī hā żi h
# end_word 212
#  hā żi hil lā hu ba' da mau ti hā , fa a mā ta hull llā hu mi `a ta 'ā min ṡum ma ba 'a ṡah , qā la kam la biṡt ,
# end_word 307
#  la biṡt , qā la la biṡ tu yau man au ba' ḍa yaụm , qā la bal la biṡ ta mi `a ta 'ā min fan ẓur i lā ṭa '
# end_word 376
#  ṭa 'ā mi ka wa sya rā bi ka lam ya ta san nah , wan ẓur i lā ḥi mā rik ,
# end_word 62
# wa iż qā la ib rā hī mu rab bi a ri nī kai fa tuḥ yil mau tā ,
# end_word 132
# mau tā , qā la a wa lam tu` min , qā la ba lā wa lā kil li yaṭ ma `in na qal b
# end_word 204
# qal bī , qā la fa khuż ar ba 'a tam mi naṭ ṭai ri fa ṣur hun na i lai ka ṡum
# end_word 222
# lai ka ṡum maj 'al 'a lā kul
# end_word 57
# ma ṡa lul la żī na yun fi qụ na am wā la hum fī sa bī lil
# end_word 113
# m fī sa bī lil lā hi ka ma ṡa li ḥab ba tin am ba tat sab 'a sa nā bi
# end_word 148
#  bi la fī kul li sum bu la tim mi `a tu
# end_word 50
# al la żī na yun fi qụ na am wā la hum fī sa bī lil
# end_word 93
# sa bī lil lā hi ṡum ma lā yut bi 'ụ na mā an fa qụ m
# end_word 137
# n fa qụ man naw wa lā a żal la hum aj ru hum 'in da r
# end_word 67
# qau lum ma' rụ fuw wa mag fi ra tun khai rum min ṣa da qa tiy yat b
# end_word 64
# yā ay yu hal la żī na ā ma nụ lā tub ṭi lụ ṣa da qā ti kum bil m
# end_word 129
# um bil man ni wal a żā kal la żī yun fi qu mā la hụ ri `ā `an nā si wa lā
# end_word 203
#  wa lā yu` mi nu bil lā hi wal yau mil ā khir , fa ma ṡa lu hụ ka ma ṡa li ṣaf w
# end_word 233
# i ṣaf wā nin 'a lai hi tu rā bun fa a
# end_word 54
# wa ma ṡa lul la żī na yun fi qụ na am wā la hu mub ti
# end_word 106
#  hu mub ti gā `a mar ḍā til lā hi wa taṡ bī tam min an fu si hi
# end_word 153
# n fu si him ka ma ṡa li jan na tim bi rab wa tin a ṣā ba
# end_word 191
# un fa ā tat u ku la hā ḍi' f
# end_word 66
# a ya wad du a ḥa du kum an ta kụ na la hụ jan na tum min na khī li
# end_word 120
#  na khī liw wa a' nā bin taj rī min taḥ ti hal an hā ru la hụ fī
# end_word 184
# hụ fī hā ming kul liṡ ṡa ma rā ti wa a ṣā ba hul ki ba ru wa la hụ żu
# end_word 239
# n ḍu 'a fā` , fa a ṣā ba hā i' ṣā run fī hi
# end_word 53
# yā ay yu hal la żī na ā ma nū an fi qụ min ṭay yi bā
# end_word 102
# y yi bā ti mā ka sab tum wa mim mā akh raj nā la kum mi n
# end_word 146
#  kum mi nal arḍ , wa lā ta yam ma mul kha bī ṡa min h
# end_word 179
# ụ na wa las tum bi `ā k
# end_word 59
# asy syai ṭā nu ya 'i du ku mul faq ra wa ya` mu ru kum bil
# end_word 100
#  bil faḥ syā` , wall llā hu ya 'i du kum mag f
# end_word 53
# yu` til ḥik ma ta may ya syā` , wa may yu` tal ḥik ma
# end_word 93
#  ḥik ma ta fa qad ụ ti ya khai rang ka ṡī rā ,
# end_word 47
# wa mā an faq tum min na fa qa tin au na żar tum
# end_word 88
# m min naż rin fa in nall llā ha ya' la muh
# end_word 52
# in tub duṣ ṣa da qā ti fa ni 'im mā hiy , wa in tukh
# end_word 101
# in tukh fụ hā wa tu` tụ hal fu qa rā `a fa hu wa khai ru
# end_word 140
#  wa yu kaf fi ru 'ang kum min
# end_word 66
# m wa lā kin nall llā ha yah dī may ya syā
# end_word 122
# may ya syā` , wa mā tun fi qụ min khai rin fa li `an fu si kum , w
# end_word 172
# kum , wa mā tun fi qụ na il lab ti gā `a waj hil lāh , wa
# end_word 55
# lil fu qa rā `il la żī na uḥ ṣi rụ fī sa bī lil lā hi l
# end_word 107
# il lā hi lā yas ta ṭī 'ụ na ḍar ban fil ar ḍi yaḥ sa bu hu mul
# end_word 153
# bu hu mul jā hi lu ag ni yā `a mi nat ta 'af fuf , ta'
# end_word 180
# f , ta' ri fu hum bi sī mā hum , lā
# end_word 65
# al la żī na yun fi qụ na am wā la hum bil lai li wan na hā ri sir
# end_word 124
# ā ri sir raw wa 'a lā ni ya tan fa la hum aj ru hum 'in da rab bi h
# end_word 80
# al la żī na ya` ku lụ nar ri bā lā ya qụ mụ na il lā ka mā ya qụ mul la żī ya ta
# end_word 143
# a żī ya ta khab ba ṭu husy syai ṭā nu mi nal mass , żā li ka bi `an na hu
# end_word 227
# ā lū in na mal bai 'u miṡ lur ri bā , wa a ḥal lall llā hul bai 'a wa ḥar ra mar
# end_word 278
# ar ri bā , fa man jā `a hụ mau 'i ẓa tum mir rab bi hī
# end_word 70
# iṣ ṣa da qāt , wall llā hu lā yu ḥib
# end_word 65
# in nal la żī na ā ma nụ wa 'a mi luṣ ṣā li ḥā ti wa a qā muṣ ṣa l
# end_word 121
#  muṣ ṣa lā ta wa ā ta wuz za kā ta la hum aj ru hum 'in da rab bi
# end_word 32
# yā ay yu hal la żī na ā ma nut t
# end_word 72
#  qull llā ha wa ża rụ mā ba qi ya mi na
# end_word 40
# fa il lam taf 'a lụ fa` ża nụ bi ḥar bim
# end_word 106
# llā hi wa ra sụ lih , wa in tub tum fa la kum ru `ụ su am
# end_word 51
# wa ing kā na żụ 'us ra tin fa na ẓi ra tun i lā mai
# end_word 84
# n i lā mai sa rah , wa an ta ṣad da qụ khai
# end_word 36
# wat ta qụ yau man tur ja 'ụ na fī hi
# end_word 83
#  i lall llāh , ṡum ma tu waf fā kul lu naf sim
# end_word 220
#  'ad li wa lā ya` ba kā ti bun ay yak tu ba ka mā 'al la ma hull llā hu fal yak tub ,
# end_word 187
# i bun ay yak tu ba ka mā 'al
# end_word 573
# l yum lil wa liy yu hụ bil 'adl , was tasy hi dụ sya hī dai ni mir ri jā li kum , fa il lam ya kụ nā ra ju lai ni fa ra ju luw wam ra `a tā ni mim man
# end_word 792
# syu ha dā `i an ta ḍil la iḥ dā hu mā fa tu żak ki ra iḥ dā hu mal ukh rā , wa lā ya` basy syu ha dā `u i żā mā du 'ụ , wa lā tas `a mū an tak tu bụ hu ṣa gī ran au ka bī ran i lā a ja lih , żā li ku
# end_word 61
# wa ing kun tum 'a lā sa fa riw wa lam ta ji dụ kā ti ban fa r
# end_word 117
# ban fa ri hā num maq bụ ḍah , fa in a mi na ba' ḍu kum ba' ḍan f
# end_word 171
#  ba' ḍan fal yu `ad dil la żi` tu mi na a mā na ta hụ wal yat ta
# end_word 200
#  yat ta qil lā ha rab bah , wa lā ta
# end_word 55
# ...
# end_word 22
# wa i żal ka wā ki bun
# end_word 20
# wa i żal bi ḥā ru fu
# end_word 20
# wa i żal qu bụ ru bu
# end_word 33
# a li mat naf sum mā qad da mat wa
# end_word 39
# yā ay yu hal in sā nu mā gar ra ka bi r
# end_word 33
# al la żī kha la qa ka fa saw wā k
# end_word 28
# fī ay yi ṣụ ra tim mā syā `a
# end_word 25
# kal lā bal tu każ żi bụ n
# end_word 23
# wa in na 'a lai kum la
# end_word 15
# ki rā mang kā t
# end_word 19
# ya' la mụ na mā taf
# end_word 20
# in nal ab rā ra la f
# end_word 23
# wa in nal fuj jā ra la
# end_word 19
# yaṣ lau na hā yau m
# end_word 21
# wa mā hum 'an hā bi g
# end_word 21
# wa mā ad rā ka mā yau
# end_word 24
# ṡum ma mā ad rā ka mā ya
# end_word 58
# yau ma lā tam li ku naf sul li naf sin syai `ā , wal am ru
# end_word 19
# wai lul lil mu ṭaf
# end_word 34
# al la żī na i żak tā lụ 'a lan nā
# end_word 32
# wa i żā kā lụ hum aw wa za nụ hu
# end_word 32
# a lā ya ẓun nu u lā `i ka an na
# end_word 13
# li yau min 'a
# end_word 31
# yau ma ya qụ mun nā su li rab b
# end_word 33
# kal lā in na ki tā bal fuj jā ri
# end_word 18
# wa mā ad rā ka mā
# end_word 13
# ki tā bum mar
# end_word 29
# wai luy yau ma `i żil lil mu
# end_word 30
# al la żī na yu każ żi bụ na bi
# end_word 38
# wa mā yu każ żi bu bi hī il lā kul lu
# end_word 41
# i żā tut lā 'a lai hi ā yā tu nā qā la a
# end_word 39
# kal lā bal rā na 'a lā qu lụ bi him mā
# end_word 43
# kal lā in na hum 'ar rab bi him yau ma `i ż
# end_word 24
# ṡum ma in na hum la ṣā l
# end_word 40
# ṡum ma yu qā lu hā żal la żī kun tum bi
# end_word 35
# kal lā in na ki tā bal ab rā ri la
# end_word 21
# wa mā ad rā ka mā 'il
# end_word 13
# ki tā bum mar
# end_word 21
# yasy ha du hul mu qar
# end_word 20
# in nal ab rā ra la f
# end_word 19
# a lal a rā `i ki ya
# end_word 31
# ta' ri fu fī wu jụ hi him naḍ r
# end_word 25
# yus qau na mir ra ḥī qim
# end_word 49
# khi tā mu hụ misk , wa fī żā li ka fal ya ta nā f
# end_word 19
# wa mi zā ju hụ min
# end_word 28
# ai nay yasy ra bu bi hal mu
# end_word 45
# in nal la żī na aj ra mụ kā nụ mi nal la żī n
# end_word 26
# wa i żā mar rụ bi him ya t
# end_word 39
# wa i żang qa la bū i lā ah li hi mung q
# end_word 37
# wa i żā ra `au hum qā lū in na hā `u
# end_word 25
# wa mā ur si lụ 'a lai him
# end_word 40
# fal yau mal la żī na ā ma nụ mi nal kuf
# end_word 19
# a lal a rā `i ki ya
# end_word 32
# hal ṡuw wi bal kuf fā ru mā kā n
# end_word 18
# i żas sa mā `un sy
# end_word 25
# wa a żi nat li rab bi hā
# end_word 16
# wa i żal ar ḍu m
# end_word 24
# wa al qat mā fī hā wa ta
# end_word 25
# wa a żi nat li rab bi hā
# end_word 53
# yā ay yu hal in sā nu in na ka kā di ḥun i lā rab bi
# end_word 31
# fa am mā man ụ ti ya ki tā ba h
# end_word 28
# fa sau fa yu ḥā sa bu ḥi sā
# end_word 28
# wa yang qa li bu i lā ah li
# end_word 34
# wa am mā man ụ ti ya ki tā ba hụ w
# end_word 18
# fa sau fa yad 'ụ ṡ
# end_word 13
# wa yaṣ lā sa
# end_word 25
# in na hụ kā na fī ah li h
# end_word 21
# in na hụ ẓan na al la
# end_word 29
# ba lā in na rab ba hụ kā na b
# end_word 20
# fa lā uq si mu bisy
# end_word 17
# wal lai li wa mā
# end_word 18
# wal qa ma ri i żat
# end_word 27
# la tar ka bun na ṭa ba qan
# end_word 19
# fa mā la hum lā yu`
# end_word 38
# wa i żā qu ri `a 'a lai hi mul qur `ā
# end_word 27
# ba lil la żī na ka fa rụ yu
# end_word 24
# wall llā hu a' la mu bi
# end_word 26
# fa basy syir hum bi 'a żā
# end_word 54
# il lal la żī na ā ma nụ wa 'a mi luṣ ṣā li ḥā ti la hu
# end_word 19
# was sa mā `i żā til
# end_word 15
# wal yau mil mau
# end_word 19
# wa syā hi diw wa ma
# end_word 19
# qu ti la aṣ ḥā bul
# end_word 16
# an nā ri żā til
# end_word 17
# iż hum 'a lai hā
# end_word 38
# wa hum 'a lā mā yaf 'a lụ na bil mu` m
# end_word 49
# wa mā na qa mụ min hum il lā ay yu` mi nụ bil lā
# end_word 40
# al la żī la hụ mul kus sa mā wā ti wal a
# end_word 51
# in nal la żī na fa ta nul mu` mi nī na wal mu` mi n
# end_word 94
#  mu` mi nā ti ṡum ma lam ya tụ bụ fa la hum 'a żā bu
# end_word 56
# in nal la żī na ā ma nụ wa 'a mi luṣ ṣā li ḥā ti la hum
# end_word 86
# ti la hum jan nā tun taj rī min taḥ ti h
# end_word 25
# in na baṭ sya rab bi ka l
# end_word 24
# in na hụ hu wa yub di `u
# end_word 19
# wa hu wal ga fụ rul
# end_word 15
# żul 'ar syil ma
# end_word 17
# fa' 'ā lul li mā
# end_word 20
# hal a tā ka ḥa dī ṡu
# end_word 15
# fir 'au na wa ṡ
# end_word 25
# ba lil la żī na ka fa rụ
# end_word 26
# wall llā hu miw wa rā `i h
# end_word 20
# bal hu wa qur `ā num
# end_word 14
# fī lau ḥim maḥ
# end_word 17
# was sa mā `i waṭ
# end_word 18
# wa mā ad rā ka maṭ
# end_word 13
# an naj muṡ ṡā
# end_word 31
# ing kul lu naf sil lam mā 'a la
# end_word 28
# fal yan ẓu ril in sā nu mim
# end_word 20
# khu li qa mim mā `in
# end_word 32
# yakh ru ju mim bai niṣ ṣul bi wa
# end_word 24
# in na hụ 'a lā raj 'i hī
# end_word 18
# yau ma tub las sa
# end_word 29
# fa mā la hụ ming quw wa tiw w
# end_word 18
# was sa mā `i żā ti
# end_word 16
# wal ar ḍi żā tiṣ
# end_word 18
# in na hụ la qau lu
# end_word 15
# wa mā hu wa bil
# end_word 20
# in na hum ya kī dụ n
# end_word 12
# wa a kī du k
# end_word 33
# fa mah hi lil kā fi rī na am hil
# end_word 22
# sab bi ḥis ma rab bi k
# end_word 20
# al la żī kha la qa f
# end_word 20
# wal la żī qad da ra
# end_word 20
# wal la żī akh ra jal
# end_word 21
# fa ja 'a la hụ gu ṡā
# end_word 20
# sa nuq ri `u ka fa l
# end_word 47
#  syā `all llāh , in na hụ ya' la mul ja
# end_word 21
# wa nu yas si ru ka li
# end_word 24
# fa żak kir in na fa 'a t
# end_word 22
# sa yaż żak ka ru may y
# end_word 21
# wa ya ta jan na bu ha
# end_word 22
# al la żī yaṣ lan nā ra
# end_word 26
# ṡum ma lā ya mụ tu fī hā w
# end_word 19
# qad af la ḥa man ta
# end_word 25
# wa ża ka ras ma rab bi hī
# end_word 25
# bal tu` ṡi rụ nal ḥa yā t
# end_word 24
# wal ā khi ra tu khai ruw
# end_word 23
# in na hā żā la fiṣ ṣu ḥ
# end_word 20
# ṣu ḥu fi ib rā hī ma
# end_word 23
# hal a tā ka ḥa dī ṡul g
# end_word 26
# wu jụ huy yau ma `i żin kh
# end_word 15
# ā mi la tun nā
# end_word 17
# taṣ lā nā ran ḥā
# end_word 20
# tus qā min 'ai nin ā
# end_word 29
# lai sa la hum ṭa 'ā mun il lā
# end_word 24
# lā yus mi nu wa lā yug n
# end_word 24
# wu jụ huy yau ma `i żin
# end_word 16
# li sa' yi hā rā
# end_word 17
# fī jan na tin 'ā
# end_word 20
# lā tas ma 'u fī hā l
# end_word 17
# fī hā 'ai nun jā
# end_word 19
# fī hā su ru rum mar
# end_word 17
# wa ak wā bum mau
# end_word 18
# wa na mā ri qu maṣ
# end_word 19
# wa za rā biy yu mab
# end_word 36
# a fa lā yan ẓu rụ na i lal i bi li k
# end_word 24
# wa i las sa mā `i kai fa
# end_word 24
# wa i lal ji bā li kai fa
# end_word 22
# wa i lal ar ḍi kai fa
# end_word 27
# fa żak kir , in na mā an ta
# end_word 23
# las ta 'a lai him bi mu
# end_word 21
# il lā man ta wal lā w
# end_word 33
# żi bu hull llā hul 'a ż
# end_word 18
# in na i lai nā i y
# end_word 25
# ṡum ma in na 'a lai nā ḥi
# end_word 7
# wal faj
# end_word 14
# wa la yā lin '
# end_word 17
# wasy syaf 'i wal
# end_word 15
# wal lai li i żā
# end_word 26
# hal fī żā li ka qa sa mul
# end_word 31
# a lam ta ra kai fa fa 'a la rab
# end_word 15
# i ra ma żā til
# end_word 31
# al la tī lam yukh laq miṡ lu hā
# end_word 32
# wa ṡa mụ dal la żī na jā buṣ ṣak
# end_word 18
# wa fir 'au na żil
# end_word 21
# al la żī na ṭa gau fi
# end_word 18
# fa ak ṡa rụ fī hal
# end_word 32
# fa ṣab ba 'a lai him rab bu ka s
# end_word 22
# in na rab ba ka la bil
# end_word 73
# fa am mal in sā nu i żā mab ta lā hu rab bu hụ fa ak ra ma hụ wa na' 'a m
# end_word 59
# wa am mā i żā mab ta lā hu fa qa da ra 'a lai hi riz qa hụ
# end_word 25
# kal lā bal lā tuk ri mụ n
# end_word 30
# wa lā ta hāḍ ḍụ na 'a lā ṭa 'ā
# end_word 28
# wa ta` ku lụ nat tu rā ṡa ak
# end_word 27
# wa tu ḥib bụ nal mā la ḥub
# end_word 31
# kal lā i żā duk ka til ar ḍu da
# end_word 33
# wa jā `a rab bu ka wal ma la ku ṣ
# end_word 71
# wa jī `a yau ma `i żim bi ja han na ma yau ma `i żiy ya ta żak ka rul i
# end_word 31
# ya qụ lu yā lai ta nī qad dam t
# end_word 35
# fa yau ma `i żil lā yu 'aż żi bu 'a
# end_word 22
# wa lā yụ ṡi qu wa ṡā q
# end_word 28
# yā ay ya tu han naf sul muṭ
# end_word 34
# ir ji 'ī i lā rab bi ki rā ḍi ya t
# end_word 16
# fad khu lī fī 'i
# end_word 15
# wad khu lī jan
# end_word 20
# lā uq si mu bi hā ża
# end_word 24
# wa an ta ḥil lum bi hā ż
# end_word 18
# wa wā li diw wa mā
# end_word 27
# la qad kha laq nal in sā na
# end_word 31
# a yaḥ sa bu al lay yaq di ra 'a
# end_word 24
# ya qụ lu ah lak tu mā la
# end_word 23
# a yaḥ sa bu al lam ya r
# end_word 21
# a lam naj 'al la hụ '
# end_word 20
# wa li sā naw wa sya
# end_word 19
# wa ha dai nā hun na
# end_word 19
# fa laq ta ḥa mal 'a
# end_word 20
# wa mā ad rā ka mal '
# end_word 12
# fak ku ra qa
# end_word 27
# au iṭ 'ā mun fī yau min żī
# end_word 17
# ya tī man żā maq
# end_word 20
# au mis kī nan żā mat
# end_word 62
# ṡum ma kā na mi nal la żī na ā ma nụ wa ta wā ṣau biṣ ṣab ri w
# end_word 22
# u lā `i ka aṣ ḥā bul m
# end_word 44
# wal la żī na ka fa rụ bi `ā yā ti nā hum aṣ
# end_word 20
# a lai him nā rum mu`
# end_word 18
# wasy syam si wa ḍu
# end_word 18
# wal qa ma ri i żā
# end_word 21
# wan na hā ri i żā jal
# end_word 19
# wal lai li i żā yag
# end_word 19
# was sa mā `i wa mā
# end_word 17
# wal ar ḍi wa mā ṭ
# end_word 19
# wa naf siw wa mā sa
# end_word 27
# fa al ha ma hā fu jụ ra hā
# end_word 19
# qad af la ḥa man za
# end_word 20
# wa qad khā ba man da
# end_word 23
# każ ża baṡ ṡa mụ du bi
# end_word 17
# i żim ba 'a ṡa as
# end_word 24
# fa qā la la hum ra sụ lu
# end_word 65
# fa każ ża bụ hu fa 'a qa rụ hā fa dam da ma 'a lai him rab bu hum
# end_word 18
# wa lā ya khā fu 'u
# end_word 17
# wal lai li i żā y
# end_word 19
# wan na hā ri i żā t
# end_word 25
# wa mā kha la qaż ża ka ra
# end_word 20
# in na sa' ya kum la
# end_word 20
# fa am mā man a' ṭā w
# end_word 17
# wa ṣad da qa bil
# end_word 23
# fa sa nu yas si ru hụ l
# end_word 24
# wa am mā mam ba khi la w
# end_word 17
# wa każ ża ba bil
# end_word 23
# fa sa nu yas si ru hụ l
# end_word 30
# wa mā yug nī 'an hu mā lu hū i
# end_word 18
# in na 'a lai nā la
# end_word 27
# wa in na la nā lal ā khi ra
# end_word 24
# fa an żar tu kum nā ran
# end_word 19
# lā yaṣ lā hā il lal
# end_word 22
# al la żī każ ża ba wa
# end_word 20
# wa sa yu jan na bu h
# end_word 26
# al la żī yu` tī mā la hụ y
# end_word 36
# wa mā li `a ḥa din 'in da hụ min ni'
# end_word 28
# il lab ti gā `a waj hi rab b
# end_word 14
# wa la sau fa y
# end_word 7
# waḍ ḍu
# end_word 15
# wal lai li i żā
# end_word 26
# mā wad da 'a ka rab bu ka
# end_word 32
# wa lal ā khi ra tu khai rul la k
# end_word 30
# wa la sau fa yu' ṭī ka rab bu
# end_word 23
# a lam ya jid ka ya tī m
# end_word 22
# wa wa ja da ka ḍāl lan
# end_word 23
# wa wa ja da ka 'ā `i la
# end_word 23
# fa am mal ya tī ma fa l
# end_word 23
# wa am mas sā `i la fa l
# end_word 30
# wa am mā bi ni' ma ti rab bi k
# end_word 21
# a lam nasy raḥ la ka
# end_word 21
# wa wa ḍa' nā 'ang ka
# end_word 19
# al la żī ang qa ḍa
# end_word 19
# wa ra fa' nā la ka
# end_word 21
# fa in na ma 'al 'us r
# end_word 19
# in na ma 'al 'us ri
# end_word 18
# fa i żā fa rag ta
# end_word 18
# wa i lā rab bi ka
# end_word 16
# wat tī ni waz za
# end_word 11
# wa ṭụ ri sī
# end_word 18
# wa hā żal ba la di
# end_word 34
# la qad kha laq nal in sā na fī aḥ
# end_word 27
# ṡum ma ra dad nā hu as fa l
# end_word 56
# il lal la żī na ā ma nụ wa 'a mi luṣ ṣā li ḥā ti fa la h
# end_word 26
# fa mā yu każ żi bu ka ba'
# end_word 30
# ai sall llā hu bi `aḥ ka mi
# end_word 28
# iq ra` bis mi rab bi kal la
# end_word 22
# kha la qal in sā na mi
# end_word 20
# iq ra` wa rab bu kal
# end_word 21
# al la żī 'al la ma bi
# end_word 24
# al la mal in sā na mā la
# end_word 23
# kal lā in nal in sā na
# end_word 14
# ar ra `ā hus t
# end_word 20
# in na i lā rab bi ka
# end_word 18
# a ra `ai tal la żī
# end_word 13
# ab dan i żā ṣ
# end_word 24
# a ra `ai ta ing kā na 'a
# end_word 15
# au a ma ra bit
# end_word 27
# a ra `ai ta ing każ ża ba w
# end_word 24
# a lam ya' lam bi `an nal
# end_word 40
# kal lā la `il lam yan ta hi la nas fa 'a
# end_word 27
# nā ṣi ya ting kā żi ba tin
# end_word 15
# fal yad 'u nā d
# end_word 17
# sa nad 'uz za bā
# end_word 29
# kal lā , lā tu ṭi' hu was jud
# end_word 27
# in nā an zal nā hu fī lai l
# end_word 24
# wa mā ad rā ka mā lai la
# end_word 32
# lai la tul qad ri khai rum min a
# end_word 59
# ta naz za lul ma lā `i ka tu war rụ ḥu fī hā bi `iż ni rab
# end_word 28
# sa lā mun hi ya ḥat tā maṭ l
# end_word 52
# lam ya ku nil la żī na ka fa rụ min ah lil ki tā bi
# end_word 84
# ki tā bi wal musy ri kī na mun fak kī na
# end_word 40
# m mi nall llā hi yat lụ ṣu ḥu fa
# end_word 20
# fī hā ku tu bung qay
# end_word 62
# wa mā ta far ra qal la żī na ụ tul ki tā ba il lā mim ba' di m
# end_word 61
#  li ya' bu dull llā ha mukh li ṣī na la hu
# end_word 106
# ī na la hud dī na ḥu na fā `a wa yu qī muṣ ṣa lā ta wa
# end_word 50
# in nal la żī na ka fa rụ min ah lil ki tā bi wal m
# end_word 98
#  bi wal musy ri kī na fī nā ri ja han na ma khā li dī na
# end_word 58
# in nal la żī na ā ma nụ wa 'a mi luṣ ṣā li ḥā ti u lā `i k
# end_word 56
# ja zā `u hum 'in da rab bi him jan nā tu 'ad nin taj rī
# end_word 89
# nin taj rī min taḥ ti hal an hā ru khā li dī
# end_word 131
# na fī hā a ba dā , ra ḍi yall llā hu 'an
# end_word 26
# i żā zul zi la til ar ḍu z
# end_word 24
# wa akh ra ja til ar ḍu a
# end_word 19
# wa qā lal in sā nu
# end_word 28
# yau ma `i żin tu ḥad di ṡu a
# end_word 22
# bi `an na rab ba ka au
# end_word 46
# yau ma `i żiy yaṣ du run nā su asy tā tal li y
# end_word 38
# fa may ya' mal miṡ qā la żar ra tin kh
# end_word 38
# wa may ya' mal miṡ qā la żar ra tin sy
# end_word 16
# wal 'ā di yā ti
# end_word 16
# fal mụ ri yā ti
# end_word 16
# fal mu gī rā ti
# end_word 17
# fa a ṡar na bi hī
# end_word 18
# fa wa saṭ na bi hī
# end_word 27
# in nal in sā na li rab bi h
# end_word 26
# wa in na hụ 'a lā żā li ka
# end_word 30
# wa in na hụ li ḥub bil khai ri
# end_word 32
# a fa lā ya' la mu i żā bu' ṡi ra
# end_word 19
# wa huṣ ṣi la mā fiṣ
# end_word 35
# in na rab ba hum bi him yau ma `i ż
# end_word 9
# al qā ri
# end_word 10
# mal qā ri
# end_word 20
# wa mā ad rā ka mal q
# end_word 33
# yau ma ya kụ nun nā su kal fa rā
# end_word 31
# wa ta kụ nul ji bā lu kal 'ih n
# end_word 25
# fa am mā man ṡa qu lat ma
# end_word 23
# fa hu wa fī 'ī sya tir
# end_word 25
# wa am mā man khaf fat ma
# end_word 15
# fa um mu hụ hā
# end_word 17
# wa mā ad rā ka mā
# end_word 12
# nā run ḥā mi
# end_word 16
# al hā ku mut ta
# end_word 20
# ḥat tā zur tu mul ma
# end_word 18
# kal lā sau fa ta'
# end_word 23
# ṡum ma kal lā sau fa ta
# end_word 28
# kal lā lau ta' la mụ na 'il
# end_word 17
# la ta ra wun nal
# end_word 29
# ṡum ma la ta ra wun na hā 'ai
# end_word 37
# ṡum ma la tus `a lun na yau ma `i żin
# end_word 7
# wal 'aṣ
# end_word 20
# in nal in sā na la f
# end_word 66
# il lal la żī na ā ma nụ wa 'a mi luṣ ṣā li ḥā ti wa ta wā ṣau bil
# end_word 29
# wai lul li kul li hu ma za ti
# end_word 27
# al la żī ja ma 'a mā law wa
# end_word 25
# yaḥ sa bu an na mā la hū
# end_word 27
# kal lā la yum ba żan na fil
# end_word 20
# wa mā ad rā ka mal ḥ
# end_word 19
# ā rull llā hil mụ
# end_word 27
# al la tī taṭ ṭa li 'u 'a la
# end_word 22
# in na hā 'a lai him mu
# end_word 19
# fī 'a ma dim mu mad
# end_word 39
# a lam ta ra kai fa fa 'a la rab bu ka b
# end_word 26
# a lam yaj 'al kai da hum f
# end_word 28
# wa ar sa la 'a lai him ṭai r
# end_word 28
# tar mī him bi ḥi jā ra tim m
# end_word 25
# fa ja 'a la hum ka 'aṣ fi
# end_word 15
# li `ī lā fi qu
# end_word 31
# ī lā fi him riḥ la tasy syi tā
# end_word 24
# fal ya' bu dụ rab ba hā
# end_word 41
# al la żī aṭ 'a ma hum min jụ 'iw wa ā ma
# end_word 28
# a ra `ai tal la żī yu każ żi
# end_word 26
# fa żā li kal la żī ya du'
# end_word 28
# wa lā ya ḥuḍ ḍu 'a lā ṭa 'ā
# end_word 19
# fa wai lul lil mu ṣ
# end_word 28
# al la żī na hum 'an ṣa lā ti
# end_word 18
# al la żī na hum yu
# end_word 17
# wa yam na 'ụ nal
# end_word 20
# in nā a' ṭai nā kal
# end_word 22
# fa ṣal li li rab bi ka
# end_word 23
# in na syā ni `a ka hu w
# end_word 19
# qul yā ay yu hal kā
# end_word 18
# lā a' bu du mā ta'
# end_word 24
# wa lā an tum 'ā bi dụ na
# end_word 24
# wa lā a na 'ā bi dum mā
# end_word 24
# wa lā an tum 'ā bi dụ na
# end_word 21
# la kum dī nu kum wa l
# end_word 19
# i żā jā `a naṣ rull
# end_word 41
# wa ra `ai tan nā sa yad khu lụ na fī dī n
# end_word 50
# fa sab biḥ bi ḥam di rab bi ka was tag fir h , in
# end_word 26
# tab bat ya dā a bī la ha b
# end_word 26
# mā ag nā 'an hu mā lu hụ w
# end_word 21
# sa yaṣ lā nā ran żā t
# end_word 26
# wam ra `a tuh , ḥam mā la
# end_word 22
# fī jī di hā ḥab lum mi
# end_word 14
# qul hu wall ll
# end_word 14
# all llā huṣ ṣa
# end_word 18
# lam ya lid wa lam
# end_word 25
# wa lam ya kul la hụ ku fu
# end_word 21
# qul a 'ụ żu bi rab bi
# end_word 17
# min syar ri mā kh
# end_word 26
# wa min syar ri gā si qin i
# end_word 29
# wa min syar rin naf fā ṡā ti
# end_word 26
# wa min syar ri ḥā si din i
# end_word 19
# qul a 'ụ żu bi rab
# end_word 10
# ma li kin
# end_word 9
# i lā hin
# end_word 25
# min syar ril was wā sil k
# end_word 27
# al la żī yu was wi su fī ṣu
# end_word 18
# mi nal jin na ti w
# ✅ Kolom 'Transcript' telah diperbaiki dan disimpan ke quran_transliteration_with_transcript_fixed.csv

# %%
import pandas as pd
import re
from difflib import SequenceMatcher

# **1️⃣ Load CSV Files**
transliteration_path = "quran_transliteration_updated.csv"
quran_v1_path = "quran_v1.csv"

# **2️⃣ Read CSV Files**
transliteration_df = pd.read_csv(transliteration_path, delimiter=";")
quran_v1_df = pd.read_csv(quran_v1_path, delimiter=";")

# **3️⃣ Ensure column names match**
transliteration_df.columns = ["Sura", "Aya", "Bagian", "Arabic", "Transliteration"]
quran_v1_df.columns = ["sura", "aya", "kemenag", "transliteration_id", "transcript", "kemenag_baru", "Bagian"]

# **4️⃣ Convert columns to string for accurate matching**
transliteration_df["Sura"] = transliteration_df["Sura"].astype(str)
transliteration_df["Aya"] = transliteration_df["Aya"].astype(str)
quran_v1_df["sura"] = quran_v1_df["sura"].astype(str)
quran_v1_df["aya"] = quran_v1_df["aya"].astype(str)

# **5️⃣ Create a dictionary mapping (sura, aya) to transcript**
transcript_dict = {
    (row["sura"], row["aya"]): row["transcript"] for _, row in quran_v1_df.iterrows()
}

# **6️⃣ Function to Find Best Matching Substring in Transcript**
def find_best_match(transliteration, full_transcript):
    """
    ✅ Mencari bagian terbaik dalam transcript yang sesuai dengan transliteration.
    ✅ Menggunakan SequenceMatcher untuk menemukan start & end terbaik.
    ✅ Menghitung panjang berdasarkan huruf saja (spasi tidak dihitung).
    """
    if not isinstance(full_transcript, str) or not isinstance(transliteration, str):
        return ""

    # **Hapus semua spasi dari transliteration dan transcript**
    translit_clean = re.sub(r"\s", "", transliteration)
    transcript_clean = re.sub(r"\s", "", full_transcript)

    # **Gunakan SequenceMatcher untuk menemukan kecocokan terbaik**
    match = SequenceMatcher(None, transcript_clean, translit_clean).find_longest_match(0, len(transcript_clean), 0, len(translit_clean))

    if match.size == 0:
        return ""  # Jika tidak ada kecocokan, kembalikan string kosong

    # **Ambil substring dengan panjang huruf sesuai transliteration**
    start = match.a  # Posisi awal dalam transcript_clean
    length = len(translit_clean)  # Jumlah huruf tanpa spasi yang harus diambil

    # **Konversi full_transcript ke bentuk list untuk mempertahankan spasi**
    result = []
    count = 0  # Hitung jumlah huruf yang sudah dimasukkan

    for char in full_transcript:
        if char.strip():  # Hanya hitung huruf, bukan spasi
            count += 1
        if start <= count <= start + length:
            result.append(char)
        if count >= start + length:
            break

    return "".join(result)  # Gabungkan kembali ke bentuk string

# **7️⃣ Add Transcript Column**
transliteration_df["Transcript"] = ""

for idx, row in transliteration_df.iterrows():
    key = (row["Sura"], row["Aya"])

    if key in transcript_dict:
        full_transcript = transcript_dict[key]
        transliteration = row["Transliteration"]
        transliteration = transliteration.replace("-","")
        # Cari bagian transcript yang paling mirip dengan transliteration
        best_match = find_best_match(transliteration, full_transcript)

        transliteration_df.at[idx, "Transcript"] = best_match

# **8️⃣ Save Updated CSV**
output_path = "quran_transliteration_with_transcript_fixed.csv"
transliteration_df.to_csv(output_path, index=False, sep=";", encoding="utf-8-sig")

print(f"✅ Kolom 'Transcript' telah diperbaiki dan disimpan ke {output_path}")
# Out:
# ✅ Kolom 'Transcript' telah diperbaiki dan disimpan ke quran_transliteration_with_transcript_fixed.csv
